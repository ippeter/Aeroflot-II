# %% [markdown]
# ## Use bonus plates (length of 4)
# ## Important notes:
# ### - new color model: number of channels = 4, one channel for each color
# ### - plate value encoded with a number: 0.1, 0.4, 1.0
# ### - v3.2: all helpers moved to external module
# ### - v3.2: hint restored: s_before is now field after 'make_move'
# ### - v3.3: debugging CNN since learning doesn't work
# ### - v3.4: try bigger CNN
# ### - v3.5: problem found. Large space of moves just doesn't work. Reduce to 1

# %%
# Needed for tests and a real game against the phone
#import pandas as pd
#import qgrid

import random as rd
import numpy as np
import tensorflow as tf

from collections import deque

import environment as ae

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Constants

# %%
# CNN
LEARNING_RATE = 0.005
UPDATE_TARGET_NET = 1000
MINIBATCH_SIZE = 64
GAMMA = 0.99

# Definitions
GAMES_TO_PLAY = 131072
REPLAY_MEMORY_SIZE = 8192
DYNAMIC_LEARNING_EPOCHS = 5
NUMBER_OF_MOVES_IN_GAME = 50

# Variables
MAXIMUM_SCORE = 0
CNN_MOVE_PROB = 0.1
CNN_MOVES_COUNT = 0
CNN_SUCCESSFUL_PREDICTION = 0
AGG_GAMES_NUMBER = 50
TOTAL_SCORE_AGG = 0.0
TOTAL_SUCCESSFUL_MOVES_AGG = 0.0

# %% [markdown]
# ### Replay Memory Buffer

# %%
#
# Replay memory buffer
#
class ExperienceBuffer():
    '''
    Experience Replay Buffer
    Inspired by Andrea Lonza
    '''

    def __init__(self, buffer_size, gamma):
        # Constants
        self.gamma = gamma
        
        # Main Replay Memory buffer parts
        self.states_before = deque(maxlen=buffer_size)
        self.actions = deque(maxlen=buffer_size)
        self.total_rewards = deque(maxlen=buffer_size)
        self.states_after = deque(maxlen=buffer_size)
        self.last_moves = deque(maxlen=buffer_size)
   
    
    def add(self, state_before, action, reward, state_after, last_move):
        # Add certain items to corresponding buffers
        self.states_before.append(state_before)
        self.actions.append(action)
        self.total_rewards.append(reward)
        self.states_after.append(state_after)
        self.last_moves.append(last_move)
    
    
    def sample_minibatch(self, minibatch_size):
        '''
        Sample a minibatch of size batch_size
        Note1: always add the most recent completed move
        '''
        indices = rd.sample(range(len(self.states_before) - 1), minibatch_size - 1)
        # Add the most recent completed move index
        indices.append(len(self.states_before) - 1)
        
        minibatch_states_before = np.array([self.states_before[i] for i in indices]) 
        minibatch_actions = np.array([self.actions[i] for i in indices]) 
        minibatch_total_rewards = np.array([self.total_rewards[i] for i in indices]) 
        minibatch_states_after = np.array([self.states_after[i] for i in indices])  
        minibatch_last_moves = np.array([self.last_moves[i] for i in indices])   
        
        return minibatch_states_before, minibatch_actions, minibatch_total_rewards, minibatch_states_after, minibatch_last_moves
    
    
    def __len__(self):
        '''
        Return length of the current replay memory buffer
        Relevant for the first *minibatch_size* moves.
        '''
        return len(self.states_before)

# %% [markdown]
# ## Deep Q-Nework

# %% [markdown]
# ### Initialize Replay Buffer

# %%
replay_memory = ExperienceBuffer(REPLAY_MEMORY_SIZE, GAMMA)

# %% [markdown]
# ### Initialize Online CNN and Target CNN

# %%
tf.random.set_seed(8)

# Initialize optimizer
online_cnn_optimizer = tf.keras.optimizers.Adam(LEARNING_RATE)

# Online CNN
Online_CNN = tf.keras.models.Sequential()
Online_CNN.add(tf.keras.layers.Conv2D(128, kernel_size=3, strides = (1, 1), padding='same', activation=tf.keras.activations.tanh, data_format='channels_last', kernel_initializer='RandomNormal', input_shape=(7, 6, 4)))
Online_CNN.add(tf.keras.layers.Conv2D(64, kernel_size=3, strides = (1, 1), padding='same', activation=tf.keras.activations.tanh, kernel_initializer='RandomNormal'))    
Online_CNN.add(tf.keras.layers.Flatten())                      
Online_CNN.add(tf.keras.layers.Dense(32, activation=tf.keras.activations.relu, kernel_initializer='RandomNormal'))
Online_CNN.add(tf.keras.layers.Dense(1, activation=tf.keras.activations.relu, kernel_initializer='RandomNormal'))

Online_CNN.compile(optimizer=online_cnn_optimizer, loss="mean_squared_error")

# Target CNN
#Target_CNN = tf.keras.models.Sequential()
#Target_CNN.add(tf.keras.layers.Conv2D(128, kernel_size=3, strides = (1, 1), padding='same', activation=tf.keras.activations.tanh, data_format = 'channels_last', kernel_initializer='RandomNormal', input_shape=(7, 6, 4)))
#Target_CNN.add(tf.keras.layers.Conv2D(64, kernel_size=3, strides = (1, 1), padding='same', activation=tf.keras.activations.tanh, kernel_initializer='RandomNormal'))    
#Target_CNN.add(tf.keras.layers.Flatten())                      
#Target_CNN.add(tf.keras.layers.Dense(32, activation=tf.keras.activations.relu, kernel_initializer='RandomNormal'))
#Target_CNN.add(tf.keras.layers.Dense(1, activation=tf.keras.activations.relu, kernel_initializer='RandomNormal'))

#Target_CNN.compile(optimizer=online_cnn_optimizer, loss="mean_squared_error")


# Set weights equal
#Target_CNN.set_weights(Online_CNN.get_weights())

# %%
# Just to see how many trainable parameters
Online_CNN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 7, 6, 128)         4736
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 7, 6, 64)          73792
# _________________________________________________________________
# flatten (Flatten)            (None, 2688)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                86048
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 164,609
# Trainable params: 164,609
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Number of moves made to follow the target CNN update strategy
total_moves = 1

# %%
#def loss(model, X, y_true, A):
#    prediction = model(X)
#    selected_action_values = tf.math.reduce_sum(prediction*A, axis=1)  
#    return tf.keras.losses.MSE(y_true, selected_action_values)


#def grad(model, inputs, targets, actions):
#    with tf.GradientTape() as tape:
#        loss_value = loss(model, inputs, targets, actions)
#    return loss_value, tape.gradient(loss_value, model.trainable_variables)

# %% [markdown]
# ## Dynamic Learning

# %%
# %%time
                                                      
for game in range(GAMES_TO_PLAY):
    # Start one game
    game_score = 0
    successful_moves = 0

    # Initialize the game field
    field = np.zeros((7, 6, 4))
    field = ae.initialize_field_3D(field)

    for m in range(NUMBER_OF_MOVES_IN_GAME):
        # Total score of one move
        reward = 0

        # Whether CNN made the move
        cnn_made_move_flag = False
        
        # If replay_memory has less than 64 moves, then make a random move
        if ((len(replay_memory) < MINIBATCH_SIZE) or (rd.random() > CNN_MOVE_PROB)):
            move = rd.randint(1, ae.ACTIONS_DIMENSION)
        else:
            # CNN selects a move
            cnn_made_move_flag = True
            CNN_MOVES_COUNT = CNN_MOVES_COUNT + 1
            #_, move = ae.predict_max_score_3D(field.copy(), Target_CNN, ae.ACTIONS_DIMENSION, ae.MOVES)
            _, move = ae.predict_max_score_3D(field.copy(), Online_CNN, ae.ACTIONS_DIMENSION, ae.MOVES)

            
        # Make the move
        new_field, plate_a, plate_b = ae.make_move_v2_3D(field.copy(), move, ae.MOVES)
        field_after_move = new_field.copy()

        # Calculate the score and update the field
        score, new_field = ae.calculate_score_v2_3D(new_field, plate_a, plate_b)
        
        # If the move is successful, then update the field and check if we have new sets        
        successful_move_flag = False

        # While we have new sets (thus the score is greater than 0), process them, calculate score and move plates
        while (score > 0.):
            if (not successful_move_flag):
                successful_moves = successful_moves + 1
                successful_move_flag = True

            # Add new points to the total score of the move
            reward = reward + score

            # Move plates downward, fill the upper row so, that it doesn't have "easy" sets of three
            # Start from the left lower corner (in order to reuse color_fits())
            new_field = ae.fill_field_3D(new_field)

            # Calculate score and check whether we have new sets
            score, new_field = ae.calculate_score_v2_3D(new_field, (-1, -1), (-1, -1))

        # Increase the score of the whole game
        game_score = game_score + reward
        
        # Check whether it's the last move of the current game
        last_move = m == NUMBER_OF_MOVES_IN_GAME - 1         

        # Add new move to the replay memory
        if (successful_move_flag):
            replay_memory.add(field_after_move, move, reward, new_field, last_move)
            
            # Update CNN move statistics
            if (cnn_made_move_flag):    
                CNN_SUCCESSFUL_PREDICTION = CNN_SUCCESSFUL_PREDICTION + 1               
                
        else:
            replay_memory.add(field_after_move, move, 0, field, last_move)   
        
        #
        # Train CNN based on the score
        #
        if (len(replay_memory) >= MINIBATCH_SIZE):
            # Select random MINIBATCH_SIZE moves from replay memory buffer
            samples = replay_memory.sample_minibatch(MINIBATCH_SIZE)

            # Prepare some things for training
            s_before = samples[0]
            actions = samples[1]
            rewards = samples[2]
            s_after = samples[3] 
            dones = samples[4]
            
            # Carefully predict next rewards: we must use predict_max_score
            rewards_next = np.zeros((64))
            
            for item in range(MINIBATCH_SIZE):
                # Calculate future rewards ONLY if current reward is NOT zero, otherwise no sense
                if (rewards[item] > 0):
                    #rewards_next[item], _ = ae.predict_max_score_3D(s_after[item], Target_CNN, ae.ACTIONS_DIMENSION, ae.MOVES)
                    rewards_next[item], _ = ae.predict_max_score_3D(s_after[item], Online_CNN, ae.ACTIONS_DIMENSION, ae.MOVES)


            #
            # Update online CNN weights: training step
            #
            actual_values = np.where(dones, rewards, rewards + GAMMA*rewards_next)
            
            #
            # This one doesn't work
            #
            
            #selected_actions = tf.one_hot(actions - 1, ae.ACTIONS_DIMENSION)
            
            #for _ in range(DYNAMIC_LEARNING_EPOCHS):             
            #    loss_value, grads = grad(Online_CNN, s_before, actual_values, selected_actions)
            #    optimizer.apply_gradients(zip(grads, Online_CNN.trainable_variables))
            
            history = Online_CNN.fit(x=s_before, y=actual_values, epochs=DYNAMIC_LEARNING_EPOCHS, verbose=0)

        # If move is successful, update the play field
        if (successful_move_flag):
            field = np.copy(new_field)
            
        # After each UPDATE_TARGET_NET moves update target CNN
        #if (total_moves % UPDATE_TARGET_NET == 0):
        #    Target_CNN.set_weights(Online_CNN.get_weights())
            
        total_moves = total_moves + 1

    #
    # Calculate and display overall stats
    #
    # Check whether we have new maximum score
    if (game_score > MAXIMUM_SCORE):
        print(f"New maximum: {game_score}, after {game} games.")
        MAXIMUM_SCORE = game_score
        
    # After each AGG_GAMES_NUMBER games output average game score, average number of successful moves per game
    TOTAL_SCORE_AGG = TOTAL_SCORE_AGG + game_score
    TOTAL_SUCCESSFUL_MOVES_AGG = TOTAL_SUCCESSFUL_MOVES_AGG + successful_moves
    
    if ((game % AGG_GAMES_NUMBER == 0) and (game > 0)):
        avg_score = TOTAL_SCORE_AGG / 500
        TOTAL_SCORE_AGG = 0.0
        
        avg_succ_moves = TOTAL_SUCCESSFUL_MOVES_AGG / 500
        TOTAL_SUCCESSFUL_MOVES_AGG = 0.0

        loss_value = history.history["loss"]
        print(f"Games: {game}, last {AGG_GAMES_NUMBER} games avg score: {avg_score}, avg of succ moves: {avg_succ_moves}, loss: {loss_value}")        
        print(f"CNN made {CNN_MOVES_COUNT} moves. Successful were {CNN_SUCCESSFUL_PREDICTION}")
        
        if (CNN_SUCCESSFUL_PREDICTION / CNN_MOVES_COUNT >= CNN_MOVE_PROB):
            CNN_MOVE_PROB = CNN_MOVE_PROB + 0.1
            
        CNN_MOVES_COUNT = 0
        CNN_SUCCESSFUL_PREDICTION = 0
# Out:
# New maximum: 45, after 0 games.
# New maximum: 48, after 1 games.
# New maximum: 51, after 2 games.
# New maximum: 57, after 4 games.
# New maximum: 58, after 6 games.
# New maximum: 61, after 9 games.
# New maximum: 78, after 13 games.
# New maximum: 81, after 20 games.
# New maximum: 96, after 22 games.
# New maximum: 98, after 29 games.
# New maximum: 116, after 35 games.
# Games: 50, last 50 games avg score: 5.646, avg of succ moves: 0.91, loss: [7447516672.0, 7441302528.0, 7435755008.0, 7435319296.0, 7435325952.0]
# CNN made 241 moves. Successful were 5
# New maximum: 132, after 55 games.
# Games: 100, last 50 games avg score: 5.13, avg of succ moves: 0.866, loss: [2413604864.0, 2336257280.0, 2337554432.0, 2337070336.0, 2335251968.0]
# CNN made 254 moves. Successful were 16
# Games: 150, last 50 games avg score: 5.906, avg of succ moves: 0.904, loss: [76795672.0, 13662234.0, 1580146.5, 1224840.0, 1224840.0]
# CNN made 253 moves. Successful were 17
# Games: 200, last 50 games avg score: 5.6, avg of succ moves: 0.868, loss: [92283944.0, 92283944.0, 92283944.0, 92283944.0, 92283944.0]
# CNN made 246 moves. Successful were 9
# Games: 250, last 50 games avg score: 5.884, avg of succ moves: 0.89, loss: [7.71875, 7.71875, 7.71875, 7.71875, 7.71875]
# CNN made 256 moves. Successful were 15
# Games: 300, last 50 games avg score: 5.214, avg of succ moves: 0.818, loss: [6.78125, 6.78125, 6.78125, 6.78125, 6.78125]
# CNN made 230 moves. Successful were 12
# New maximum: 149, after 306 games.
# Games: 350, last 50 games avg score: 6.47, avg of succ moves: 0.894, loss: [11.09375, 11.09375, 11.09375, 11.09375, 11.09375]
# CNN made 240 moves. Successful were 15
# Games: 400, last 50 games avg score: 5.586, avg of succ moves: 0.85, loss: [11.640625, 11.640625, 11.640625, 11.640625, 11.640625]
# CNN made 249 moves. Successful were 9
# Games: 450, last 50 games avg score: 5.224, avg of succ moves: 0.878, loss: [10.765625, 10.765625, 10.765625, 10.765625, 10.765625]
# CNN made 256 moves. Successful were 12
# Games: 500, last 50 games avg score: 5.83, avg of succ moves: 0.938, loss: [17.84375, 17.84375, 17.84375, 17.84375, 17.84375]
# CNN made 254 moves. Successful were 16
# Games: 550, last 50 games avg score: 5.812, avg of succ moves: 0.862, loss: [29.203125, 29.203125, 29.203125, 29.203125, 29.203125]
# CNN made 253 moves. Successful were 13
# New maximum: 163, after 551 games.
# Games: 600, last 50 games avg score: 5.63, avg of succ moves: 0.876, loss: [7.8125, 7.8125, 7.8125, 7.8125, 7.8125]
# CNN made 254 moves. Successful were 16
# Games: 650, last 50 games avg score: 6.01, avg of succ moves: 0.932, loss: [10.109375, 10.109375, 10.109375, 10.109375, 10.109375]
# CNN made 250 moves. Successful were 16
# Games: 700, last 50 games avg score: 6.346, avg of succ moves: 0.926, loss: [10.65625, 10.65625, 10.65625, 10.65625, 10.65625]
# CNN made 246 moves. Successful were 13
# Games: 750, last 50 games avg score: 6.35, avg of succ moves: 0.942, loss: [16.6875, 16.6875, 16.6875, 16.6875, 16.6875]
# CNN made 241 moves. Successful were 15
# Games: 800, last 50 games avg score: 5.742, avg of succ moves: 0.896, loss: [3.109375, 3.109375, 3.109375, 3.109375, 3.109375]
# CNN made 275 moves. Successful were 16
# Games: 850, last 50 games avg score: 5.512, avg of succ moves: 0.864, loss: [46.984375, 46.984375, 46.984375, 46.984375, 46.984375]
# CNN made 275 moves. Successful were 16
# Games: 900, last 50 games avg score: 6.09, avg of succ moves: 0.956, loss: [12.9375, 12.9375, 12.9375, 12.9375, 12.9375]
# CNN made 215 moves. Successful were 16
# Games: 950, last 50 games avg score: 7.078, avg of succ moves: 1.036, loss: [34.71875, 34.71875, 34.71875, 34.71875, 34.71875]
# CNN made 239 moves. Successful were 13
# Games: 1000, last 50 games avg score: 5.944, avg of succ moves: 0.904, loss: [19.953125, 19.953125, 19.953125, 19.953125, 19.953125]
# CNN made 247 moves. Successful were 16
# Games: 1050, last 50 games avg score: 6.912, avg of succ moves: 0.99, loss: [8.59375, 8.59375, 8.59375, 8.59375, 8.59375]
# CNN made 246 moves. Successful were 15
# Games: 1100, last 50 games avg score: 5.796, avg of succ moves: 0.85, loss: [6.625, 6.625, 6.625, 6.625, 6.625]
# CNN made 258 moves. Successful were 17
# Games: 1150, last 50 games avg score: 6.268, avg of succ moves: 0.964, loss: [13.84375, 13.84375, 13.84375, 13.84375, 13.84375]
# CNN made 259 moves. Successful were 17
# Games: 1200, last 50 games avg score: 5.586, avg of succ moves: 0.832, loss: [3.34375, 3.34375, 3.34375, 3.34375, 3.34375]
# CNN made 264 moves. Successful were 15
# New maximum: 168, after 1229 games.
# Games: 1250, last 50 games avg score: 5.98, avg of succ moves: 0.884, loss: [41.15625, 41.15625, 41.15625, 41.15625, 41.15625]
# CNN made 238 moves. Successful were 14
# Games: 1300, last 50 games avg score: 5.694, avg of succ moves: 0.884, loss: [48.921875, 48.921875, 48.921875, 48.921875, 48.921875]
# CNN made 245 moves. Successful were 13
# Games: 1350, last 50 games avg score: 5.874, avg of succ moves: 0.878, loss: [20.890625, 20.890625, 20.890625, 20.890625, 20.890625]
# CNN made 235 moves. Successful were 7
# Games: 1400, last 50 games avg score: 6.322, avg of succ moves: 0.916, loss: [36.4375, 36.4375, 36.4375, 36.4375, 36.4375]
# CNN made 257 moves. Successful were 22
# Games: 1450, last 50 games avg score: 5.948, avg of succ moves: 0.892, loss: [3.625, 3.625, 3.625, 3.625, 3.625]
# CNN made 250 moves. Successful were 11
# Games: 1500, last 50 games avg score: 6.276, avg of succ moves: 0.936, loss: [7.28125, 7.28125, 7.28125, 7.28125, 7.28125]
# CNN made 251 moves. Successful were 18
# Games: 1550, last 50 games avg score: 6.172, avg of succ moves: 0.886, loss: [5.625, 5.625, 5.625, 5.625, 5.625]
# CNN made 252 moves. Successful were 14
# Games: 1600, last 50 games avg score: 6.084, avg of succ moves: 0.956, loss: [1.265625, 1.265625, 1.265625, 1.265625, 1.265625]
# CNN made 241 moves. Successful were 12
# Games: 1650, last 50 games avg score: 5.802, avg of succ moves: 0.9, loss: [6.90625, 6.90625, 6.90625, 6.90625, 6.90625]
# CNN made 273 moves. Successful were 19
# New maximum: 176, after 1691 games.
# Games: 1700, last 50 games avg score: 6.176, avg of succ moves: 0.914, loss: [13.53125, 13.53125, 13.53125, 13.53125, 13.53125]
# CNN made 239 moves. Successful were 11
# Games: 1750, last 50 games avg score: 5.976, avg of succ moves: 0.934, loss: [7.6875, 7.6875, 7.6875, 7.6875, 7.6875]
# CNN made 263 moves. Successful were 12
# Games: 1800, last 50 games avg score: 6.452, avg of succ moves: 0.938, loss: [4.109375, 4.109375, 4.109375, 4.109375, 4.109375]
# CNN made 253 moves. Successful were 13
# Games: 1850, last 50 games avg score: 5.956, avg of succ moves: 0.898, loss: [13.71875, 13.71875, 13.71875, 13.71875, 13.71875]
# CNN made 252 moves. Successful were 14
# Games: 1900, last 50 games avg score: 6.46, avg of succ moves: 0.906, loss: [14.671875, 14.671875, 14.671875, 14.671875, 14.671875]
# CNN made 220 moves. Successful were 10
# Games: 1950, last 50 games avg score: 6.098, avg of succ moves: 0.978, loss: [9.75, 9.75, 9.75, 9.75, 9.75]
# CNN made 228 moves. Successful were 7
# Games: 2000, last 50 games avg score: 5.514, avg of succ moves: 0.852, loss: [5.6875, 5.6875, 5.6875, 5.6875, 5.6875]
# CNN made 262 moves. Successful were 13
# Games: 2050, last 50 games avg score: 5.984, avg of succ moves: 0.954, loss: [7.359375, 7.359375, 7.359375, 7.359375, 7.359375]
# CNN made 251 moves. Successful were 16
# Games: 2100, last 50 games avg score: 6.078, avg of succ moves: 0.912, loss: [9.453125, 9.453125, 9.453125, 9.453125, 9.453125]
# CNN made 248 moves. Successful were 4
# Games: 2150, last 50 games avg score: 5.674, avg of succ moves: 0.862, loss: [14.53125, 14.53125, 14.53125, 14.53125, 14.53125]
# CNN made 254 moves. Successful were 20
# Games: 2200, last 50 games avg score: 6.024, avg of succ moves: 0.958, loss: [15.796875, 15.796875, 15.796875, 15.796875, 15.796875]
# CNN made 256 moves. Successful were 13
# Games: 2250, last 50 games avg score: 6.994, avg of succ moves: 1.002, loss: [2.5, 2.5, 2.5, 2.5, 2.5]
# CNN made 245 moves. Successful were 14
# Games: 2300, last 50 games avg score: 6.008, avg of succ moves: 0.922, loss: [18.671875, 18.671875, 18.671875, 18.671875, 18.671875]
# CNN made 240 moves. Successful were 9
# Games: 2350, last 50 games avg score: 5.924, avg of succ moves: 0.936, loss: [19.875, 19.875, 19.875, 19.875, 19.875]
# CNN made 249 moves. Successful were 13
# Games: 2400, last 50 games avg score: 6.092, avg of succ moves: 0.942, loss: [14.984375, 14.984375, 14.984375, 14.984375, 14.984375]
# CNN made 224 moves. Successful were 18
# New maximum: 182, after 2446 games.
# Games: 2450, last 50 games avg score: 6.716, avg of succ moves: 0.98, loss: [16.984375, 16.984375, 16.984375, 16.984375, 16.984375]
# CNN made 260 moves. Successful were 19
# Games: 2500, last 50 games avg score: 5.162, avg of succ moves: 0.804, loss: [7.78125, 7.78125, 7.78125, 7.78125, 7.78125]
# CNN made 240 moves. Successful were 9
# Games: 2550, last 50 games avg score: 5.812, avg of succ moves: 0.856, loss: [17.9375, 17.9375, 17.9375, 17.9375, 17.9375]
# CNN made 255 moves. Successful were 11
# Games: 2600, last 50 games avg score: 6.318, avg of succ moves: 0.948, loss: [18.96875, 18.96875, 18.96875, 18.96875, 18.96875]
# CNN made 227 moves. Successful were 23
# Games: 2650, last 50 games avg score: 5.296, avg of succ moves: 0.772, loss: [4.671875, 4.671875, 4.671875, 4.671875, 4.671875]
# CNN made 503 moves. Successful were 19
# Games: 2700, last 50 games avg score: 5.15, avg of succ moves: 0.828, loss: [9.125, 9.125, 9.125, 9.125, 9.125]
# CNN made 495 moves. Successful were 17
# Games: 2750, last 50 games avg score: 5.872, avg of succ moves: 0.9, loss: [6.609375, 6.609375, 6.609375, 6.609375, 6.609375]
# CNN made 484 moves. Successful were 34
# Games: 2800, last 50 games avg score: 5.036, avg of succ moves: 0.774, loss: [13.78125, 13.78125, 13.78125, 13.78125, 13.78125]
# CNN made 468 moves. Successful were 17
# Games: 2850, last 50 games avg score: 5.872, avg of succ moves: 0.846, loss: [22.234375, 22.234375, 22.234375, 22.234375, 22.234375]
# CNN made 528 moves. Successful were 22
# Games: 2900, last 50 games avg score: 4.914, avg of succ moves: 0.786, loss: [25.03125, 25.03125, 25.03125, 25.03125, 25.03125]
# CNN made 504 moves. Successful were 17
# Games: 2950, last 50 games avg score: 5.22, avg of succ moves: 0.872, loss: [19.25, 19.25, 19.25, 19.25, 19.25]
# CNN made 480 moves. Successful were 23
# New maximum: 202, after 2977 games.
# Games: 3000, last 50 games avg score: 5.518, avg of succ moves: 0.844, loss: [3.828125, 3.828125, 3.828125, 3.828125, 3.828125]
# CNN made 499 moves. Successful were 23
# Games: 3050, last 50 games avg score: 5.942, avg of succ moves: 0.874, loss: [12.265625, 12.265625, 12.265625, 12.265625, 12.265625]
# CNN made 500 moves. Successful were 16
# Games: 3100, last 50 games avg score: 5.146, avg of succ moves: 0.806, loss: [10.859375, 10.859375, 10.859375, 10.859375, 10.859375]
# CNN made 500 moves. Successful were 15
# Games: 3150, last 50 games avg score: 5.62, avg of succ moves: 0.85, loss: [25.703125, 25.703125, 25.703125, 25.703125, 25.703125]
# CNN made 493 moves. Successful were 23
# Games: 3200, last 50 games avg score: 5.41, avg of succ moves: 0.874, loss: [10.4375, 10.4375, 10.4375, 10.4375, 10.4375]
# CNN made 473 moves. Successful were 23
# Games: 3250, last 50 games avg score: 5.098, avg of succ moves: 0.792, loss: [16.28125, 16.28125, 16.28125, 16.28125, 16.28125]
# CNN made 502 moves. Successful were 19
# Games: 3300, last 50 games avg score: 5.13, avg of succ moves: 0.804, loss: [10.484375, 10.484375, 10.484375, 10.484375, 10.484375]
# CNN made 519 moves. Successful were 17
# Games: 3350, last 50 games avg score: 5.066, avg of succ moves: 0.788, loss: [6.21875, 6.21875, 6.21875, 6.21875, 6.21875]
# CNN made 501 moves. Successful were 18
# Games: 3400, last 50 games avg score: 4.838, avg of succ moves: 0.758, loss: [39.703125, 39.703125, 39.703125, 39.703125, 39.703125]
# CNN made 480 moves. Successful were 19
# Games: 3450, last 50 games avg score: 6.036, avg of succ moves: 0.89, loss: [22.15625, 22.15625, 22.15625, 22.15625, 22.15625]
# CNN made 523 moves. Successful were 23
# Games: 3500, last 50 games avg score: 4.926, avg of succ moves: 0.8, loss: [11.640625, 11.640625, 11.640625, 11.640625, 11.640625]
# CNN made 504 moves. Successful were 15
# Games: 3550, last 50 games avg score: 5.37, avg of succ moves: 0.834, loss: [15.640625, 15.640625, 15.640625, 15.640625, 15.640625]
# CNN made 527 moves. Successful were 22
# Games: 3600, last 50 games avg score: 5.748, avg of succ moves: 0.862, loss: [14.96875, 14.96875, 14.96875, 14.96875, 14.96875]
# CNN made 525 moves. Successful were 30
# Games: 3650, last 50 games avg score: 4.678, avg of succ moves: 0.808, loss: [4.046875, 4.046875, 4.046875, 4.046875, 4.046875]
# CNN made 470 moves. Successful were 17
# Games: 3700, last 50 games avg score: 5.488, avg of succ moves: 0.868, loss: [4.984375, 4.984375, 4.984375, 4.984375, 4.984375]
# CNN made 455 moves. Successful were 26
# Games: 3750, last 50 games avg score: 5.14, avg of succ moves: 0.816, loss: [4.796875, 4.796875, 4.796875, 4.796875, 4.796875]
# CNN made 543 moves. Successful were 22
# Games: 3800, last 50 games avg score: 5.278, avg of succ moves: 0.868, loss: [13.9375, 13.9375, 13.9375, 13.9375, 13.9375]
# CNN made 510 moves. Successful were 26
# Games: 3850, last 50 games avg score: 4.648, avg of succ moves: 0.762, loss: [7.203125, 7.203125, 7.203125, 7.203125, 7.203125]
# CNN made 517 moves. Successful were 22
# Games: 3900, last 50 games avg score: 5.516, avg of succ moves: 0.818, loss: [7.890625, 7.890625, 7.890625, 7.890625, 7.890625]
# CNN made 477 moves. Successful were 17
# Games: 3950, last 50 games avg score: 5.084, avg of succ moves: 0.732, loss: [14.03125, 14.03125, 14.03125, 14.03125, 14.03125]
# CNN made 511 moves. Successful were 16
# Games: 4000, last 50 games avg score: 4.842, avg of succ moves: 0.834, loss: [9.515625, 9.515625, 9.515625, 9.515625, 9.515625]
# CNN made 477 moves. Successful were 17
# Games: 4050, last 50 games avg score: 4.782, avg of succ moves: 0.806, loss: [11.84375, 11.84375, 11.84375, 11.84375, 11.84375]
# CNN made 510 moves. Successful were 16
# Games: 4100, last 50 games avg score: 5.23, avg of succ moves: 0.816, loss: [8.46875, 8.46875, 8.46875, 8.46875, 8.46875]
# CNN made 504 moves. Successful were 16
# Games: 4150, last 50 games avg score: 5.466, avg of succ moves: 0.862, loss: [4.328125, 4.328125, 4.328125, 4.328125, 4.328125]
# CNN made 528 moves. Successful were 22
# Games: 4200, last 50 games avg score: 5.476, avg of succ moves: 0.86, loss: [10.765625, 10.765625, 10.765625, 10.765625, 10.765625]
# CNN made 476 moves. Successful were 23
# Games: 4250, last 50 games avg score: 5.22, avg of succ moves: 0.858, loss: [30.5, 30.5, 30.5, 30.5, 30.5]
# CNN made 527 moves. Successful were 15
# Games: 4300, last 50 games avg score: 5.206, avg of succ moves: 0.836, loss: [8.609375, 8.609375, 8.609375, 8.609375, 8.609375]
# CNN made 490 moves. Successful were 25
# Games: 4350, last 50 games avg score: 5.64, avg of succ moves: 0.83, loss: [23.453125, 23.453125, 23.453125, 23.453125, 23.453125]
# CNN made 482 moves. Successful were 18
# Games: 4400, last 50 games avg score: 5.614, avg of succ moves: 0.82, loss: [16.375, 16.375, 16.375, 16.375, 16.375]
# CNN made 527 moves. Successful were 11
# Games: 4450, last 50 games avg score: 5.938, avg of succ moves: 0.856, loss: [23.40625, 23.40625, 23.40625, 23.40625, 23.40625]
# CNN made 492 moves. Successful were 23
# Games: 4500, last 50 games avg score: 5.162, avg of succ moves: 0.838, loss: [2.671875, 2.671875, 2.671875, 2.671875, 2.671875]
# CNN made 511 moves. Successful were 24
# Games: 4550, last 50 games avg score: 5.586, avg of succ moves: 0.842, loss: [24.203125, 24.203125, 24.203125, 24.203125, 24.203125]
# CNN made 511 moves. Successful were 19
# Games: 4600, last 50 games avg score: 5.096, avg of succ moves: 0.78, loss: [3.3125, 3.3125, 3.3125, 3.3125, 3.3125]
# CNN made 494 moves. Successful were 13
# Games: 4650, last 50 games avg score: 5.144, avg of succ moves: 0.838, loss: [4.5, 4.5, 4.5, 4.5, 4.5]
# CNN made 509 moves. Successful were 23
# Games: 4700, last 50 games avg score: 4.658, avg of succ moves: 0.764, loss: [6.5, 6.5, 6.5, 6.5, 6.5]
# CNN made 528 moves. Successful were 16
# Games: 4750, last 50 games avg score: 6.228, avg of succ moves: 0.872, loss: [4.796875, 4.796875, 4.796875, 4.796875, 4.796875]
# CNN made 482 moves. Successful were 24
# Games: 4800, last 50 games avg score: 5.43, avg of succ moves: 0.822, loss: [28.6875, 28.6875, 28.6875, 28.6875, 28.6875]
# CNN made 468 moves. Successful were 20
# Games: 4850, last 50 games avg score: 5.61, avg of succ moves: 0.854, loss: [21.453125, 21.453125, 21.453125, 21.453125, 21.453125]
# CNN made 492 moves. Successful were 18
# Games: 4900, last 50 games avg score: 5.202, avg of succ moves: 0.836, loss: [12.90625, 12.90625, 12.90625, 12.90625, 12.90625]
# CNN made 484 moves. Successful were 14
# Games: 4950, last 50 games avg score: 5.798, avg of succ moves: 0.822, loss: [49.484375, 49.484375, 49.484375, 49.484375, 49.484375]
# CNN made 485 moves. Successful were 18
# Games: 5000, last 50 games avg score: 4.67, avg of succ moves: 0.792, loss: [8.484375, 8.484375, 8.484375, 8.484375, 8.484375]
# CNN made 537 moves. Successful were 19
# Games: 5050, last 50 games avg score: 5.182, avg of succ moves: 0.768, loss: [5.6875, 5.6875, 5.6875, 5.6875, 5.6875]
# CNN made 506 moves. Successful were 11
# Games: 5100, last 50 games avg score: 5.516, avg of succ moves: 0.78, loss: [12.90625, 12.90625, 12.90625, 12.90625, 12.90625]
# CNN made 482 moves. Successful were 7
# Games: 5150, last 50 games avg score: 5.032, avg of succ moves: 0.778, loss: [4.28125, 4.28125, 4.28125, 4.28125, 4.28125]
# CNN made 532 moves. Successful were 17
# Games: 5200, last 50 games avg score: 5.726, avg of succ moves: 0.868, loss: [8.921875, 8.921875, 8.921875, 8.921875, 8.921875]
# CNN made 519 moves. Successful were 19
# Games: 5250, last 50 games avg score: 5.334, avg of succ moves: 0.84, loss: [4.15625, 4.15625, 4.15625, 4.15625, 4.15625]
# CNN made 504 moves. Successful were 16
# Games: 5300, last 50 games avg score: 5.29, avg of succ moves: 0.836, loss: [10.640625, 10.640625, 10.640625, 10.640625, 10.640625]
# CNN made 495 moves. Successful were 21
# Games: 5350, last 50 games avg score: 5.788, avg of succ moves: 0.846, loss: [5.5625, 5.5625, 5.5625, 5.5625, 5.5625]
# CNN made 498 moves. Successful were 26
# Games: 5400, last 50 games avg score: 5.232, avg of succ moves: 0.814, loss: [16.71875, 16.71875, 16.71875, 16.71875, 16.71875]
# CNN made 498 moves. Successful were 22
# Games: 5450, last 50 games avg score: 5.382, avg of succ moves: 0.878, loss: [10.8125, 10.8125, 10.8125, 10.8125, 10.8125]
# CNN made 492 moves. Successful were 28
# Games: 5500, last 50 games avg score: 5.31, avg of succ moves: 0.876, loss: [19.90625, 19.90625, 19.90625, 19.90625, 19.90625]
# CNN made 508 moves. Successful were 21
# Games: 5550, last 50 games avg score: 6.104, avg of succ moves: 0.912, loss: [5.203125, 5.203125, 5.203125, 5.203125, 5.203125]
# CNN made 500 moves. Successful were 20
# Games: 5600, last 50 games avg score: 5.524, avg of succ moves: 0.834, loss: [47.15625, 47.15625, 47.15625, 47.15625, 47.15625]
# CNN made 521 moves. Successful were 24
# Games: 5650, last 50 games avg score: 5.104, avg of succ moves: 0.83, loss: [7.546875, 7.546875, 7.546875, 7.546875, 7.546875]
# CNN made 478 moves. Successful were 22
# Games: 5700, last 50 games avg score: 5.15, avg of succ moves: 0.774, loss: [11.609375, 11.609375, 11.609375, 11.609375, 11.609375]
# CNN made 491 moves. Successful were 19
# Games: 5750, last 50 games avg score: 5.46, avg of succ moves: 0.836, loss: [7.28125, 7.28125, 7.28125, 7.28125, 7.28125]
# CNN made 497 moves. Successful were 21
# Games: 5800, last 50 games avg score: 5.758, avg of succ moves: 0.874, loss: [8.53125, 8.53125, 8.53125, 8.53125, 8.53125]
# CNN made 500 moves. Successful were 24
# Games: 5850, last 50 games avg score: 5.086, avg of succ moves: 0.812, loss: [18.375, 18.375, 18.375, 18.375, 18.375]
# CNN made 459 moves. Successful were 17
# Games: 5900, last 50 games avg score: 5.116, avg of succ moves: 0.774, loss: [8.78125, 8.78125, 8.78125, 8.78125, 8.78125]
# CNN made 524 moves. Successful were 16
# Games: 5950, last 50 games avg score: 5.606, avg of succ moves: 0.896, loss: [10.140625, 10.140625, 10.140625, 10.140625, 10.140625]
# CNN made 474 moves. Successful were 20
# Games: 6000, last 50 games avg score: 5.3, avg of succ moves: 0.786, loss: [11.953125, 11.953125, 11.953125, 11.953125, 11.953125]
# CNN made 515 moves. Successful were 8
# Games: 6050, last 50 games avg score: 5.316, avg of succ moves: 0.848, loss: [11.53125, 11.53125, 11.53125, 11.53125, 11.53125]
# CNN made 520 moves. Successful were 26
# Games: 6100, last 50 games avg score: 5.352, avg of succ moves: 0.908, loss: [7.375, 7.375, 7.375, 7.375, 7.375]
# CNN made 481 moves. Successful were 21
# Games: 6150, last 50 games avg score: 5.032, avg of succ moves: 0.782, loss: [8.3125, 8.3125, 8.3125, 8.3125, 8.3125]
# CNN made 480 moves. Successful were 23
# Games: 6200, last 50 games avg score: 5.522, avg of succ moves: 0.848, loss: [4.578125, 4.578125, 4.578125, 4.578125, 4.578125]
# CNN made 531 moves. Successful were 20
# Games: 6250, last 50 games avg score: 5.274, avg of succ moves: 0.82, loss: [3.421875, 3.421875, 3.421875, 3.421875, 3.421875]
# CNN made 507 moves. Successful were 29
# Games: 6300, last 50 games avg score: 5.156, avg of succ moves: 0.802, loss: [17.71875, 17.71875, 17.71875, 17.71875, 17.71875]
# CNN made 477 moves. Successful were 25
# Games: 6350, last 50 games avg score: 4.834, avg of succ moves: 0.744, loss: [13.109375, 13.109375, 13.109375, 13.109375, 13.109375]
# CNN made 538 moves. Successful were 18
# Games: 6400, last 50 games avg score: 5.484, avg of succ moves: 0.816, loss: [10.984375, 10.984375, 10.984375, 10.984375, 10.984375]
# CNN made 508 moves. Successful were 21
# Games: 6450, last 50 games avg score: 5.074, avg of succ moves: 0.768, loss: [16.828125, 16.828125, 16.828125, 16.828125, 16.828125]
# CNN made 447 moves. Successful were 14
# Games: 6500, last 50 games avg score: 5.336, avg of succ moves: 0.766, loss: [5.90625, 5.90625, 5.90625, 5.90625, 5.90625]
# CNN made 497 moves. Successful were 17
# Games: 6550, last 50 games avg score: 5.872, avg of succ moves: 0.896, loss: [9.8125, 9.8125, 9.8125, 9.8125, 9.8125]
# CNN made 512 moves. Successful were 23
# Games: 6600, last 50 games avg score: 5.05, avg of succ moves: 0.764, loss: [7.734375, 7.734375, 7.734375, 7.734375, 7.734375]
# CNN made 528 moves. Successful were 17
# Games: 6650, last 50 games avg score: 4.94, avg of succ moves: 0.792, loss: [9.625, 9.625, 9.625, 9.625, 9.625]
# CNN made 540 moves. Successful were 17
# Games: 6700, last 50 games avg score: 5.466, avg of succ moves: 0.818, loss: [13.546875, 13.546875, 13.546875, 13.546875, 13.546875]
# CNN made 536 moves. Successful were 23
# Games: 6750, last 50 games avg score: 5.476, avg of succ moves: 0.804, loss: [6.109375, 6.109375, 6.109375, 6.109375, 6.109375]
# CNN made 494 moves. Successful were 22
# Games: 6800, last 50 games avg score: 5.274, avg of succ moves: 0.824, loss: [2.40625, 2.40625, 2.40625, 2.40625, 2.40625]
# CNN made 515 moves. Successful were 18
# Games: 6850, last 50 games avg score: 5.876, avg of succ moves: 0.84, loss: [26.828125, 26.828125, 26.828125, 26.828125, 26.828125]
# CNN made 490 moves. Successful were 27
# Games: 6900, last 50 games avg score: 5.132, avg of succ moves: 0.82, loss: [2.21875, 2.21875, 2.21875, 2.21875, 2.21875]
# CNN made 517 moves. Successful were 13
# Games: 6950, last 50 games avg score: 5.138, avg of succ moves: 0.806, loss: [3.796875, 3.796875, 3.796875, 3.796875, 3.796875]
# CNN made 471 moves. Successful were 14
# Games: 7000, last 50 games avg score: 5.7, avg of succ moves: 0.888, loss: [5.03125, 5.03125, 5.03125, 5.03125, 5.03125]
# CNN made 538 moves. Successful were 23
# Games: 7050, last 50 games avg score: 5.61, avg of succ moves: 0.822, loss: [2.6875, 2.6875, 2.6875, 2.6875, 2.6875]
# CNN made 499 moves. Successful were 16
# Games: 7100, last 50 games avg score: 4.974, avg of succ moves: 0.788, loss: [19.3125, 19.3125, 19.3125, 19.3125, 19.3125]
# CNN made 532 moves. Successful were 16
# Games: 7150, last 50 games avg score: 4.89, avg of succ moves: 0.812, loss: [5.453125, 5.453125, 5.453125, 5.453125, 5.453125]
# CNN made 476 moves. Successful were 12
# Games: 7200, last 50 games avg score: 5.542, avg of succ moves: 0.814, loss: [5.46875, 5.46875, 5.46875, 5.46875, 5.46875]
# CNN made 499 moves. Successful were 9
# Games: 7250, last 50 games avg score: 5.384, avg of succ moves: 0.842, loss: [17.109375, 17.109375, 17.109375, 17.109375, 17.109375]
# CNN made 533 moves. Successful were 25
# Games: 7300, last 50 games avg score: 5.616, avg of succ moves: 0.896, loss: [10.484375, 10.484375, 10.484375, 10.484375, 10.484375]
# CNN made 517 moves. Successful were 19
# Games: 7350, last 50 games avg score: 5.41, avg of succ moves: 0.818, loss: [10.015625, 10.015625, 10.015625, 10.015625, 10.015625]
# CNN made 470 moves. Successful were 19
# Games: 7400, last 50 games avg score: 6.172, avg of succ moves: 0.908, loss: [9.671875, 9.671875, 9.671875, 9.671875, 9.671875]
# CNN made 542 moves. Successful were 33
# Games: 7450, last 50 games avg score: 5.544, avg of succ moves: 0.856, loss: [46.9375, 46.9375, 46.9375, 46.9375, 46.9375]
# CNN made 495 moves. Successful were 20
# Games: 7500, last 50 games avg score: 5.708, avg of succ moves: 0.92, loss: [3.640625, 3.640625, 3.640625, 3.640625, 3.640625]
# CNN made 471 moves. Successful were 31
# Games: 7550, last 50 games avg score: 5.484, avg of succ moves: 0.768, loss: [25.03125, 25.03125, 25.03125, 25.03125, 25.03125]
# CNN made 502 moves. Successful were 9
# Games: 7600, last 50 games avg score: 6.112, avg of succ moves: 0.876, loss: [7.953125, 7.953125, 7.953125, 7.953125, 7.953125]
# CNN made 508 moves. Successful were 19
# Games: 7650, last 50 games avg score: 6.01, avg of succ moves: 0.848, loss: [7.0, 7.0, 7.0, 7.0, 7.0]
# CNN made 494 moves. Successful were 26
# Games: 7700, last 50 games avg score: 4.672, avg of succ moves: 0.794, loss: [14.46875, 14.46875, 14.46875, 14.46875, 14.46875]
# CNN made 500 moves. Successful were 23
# Games: 7750, last 50 games avg score: 5.276, avg of succ moves: 0.828, loss: [11.8125, 11.8125, 11.8125, 11.8125, 11.8125]
# CNN made 534 moves. Successful were 22
# Games: 7800, last 50 games avg score: 5.038, avg of succ moves: 0.844, loss: [2.953125, 2.953125, 2.953125, 2.953125, 2.953125]
# CNN made 509 moves. Successful were 20
# Games: 7850, last 50 games avg score: 5.76, avg of succ moves: 0.862, loss: [9.25, 9.25, 9.25, 9.25, 9.25]
# CNN made 487 moves. Successful were 16
# Games: 7900, last 50 games avg score: 5.324, avg of succ moves: 0.858, loss: [15.625, 15.625, 15.625, 15.625, 15.625]
# CNN made 485 moves. Successful were 18
# Games: 7950, last 50 games avg score: 5.428, avg of succ moves: 0.826, loss: [5.625, 5.625, 5.625, 5.625, 5.625]
# CNN made 489 moves. Successful were 17
# Games: 8000, last 50 games avg score: 5.54, avg of succ moves: 0.854, loss: [26.8125, 26.8125, 26.8125, 26.8125, 26.8125]
# CNN made 493 moves. Successful were 19
# Games: 8050, last 50 games avg score: 5.382, avg of succ moves: 0.828, loss: [14.921875, 14.921875, 14.921875, 14.921875, 14.921875]
# CNN made 503 moves. Successful were 20
# Games: 8100, last 50 games avg score: 5.554, avg of succ moves: 0.848, loss: [7.65625, 7.65625, 7.65625, 7.65625, 7.65625]
# CNN made 492 moves. Successful were 38
# Games: 8150, last 50 games avg score: 4.84, avg of succ moves: 0.802, loss: [37.546875, 37.546875, 37.546875, 37.546875, 37.546875]
# CNN made 522 moves. Successful were 21
# Games: 8200, last 50 games avg score: 5.432, avg of succ moves: 0.832, loss: [18.390625, 18.390625, 18.390625, 18.390625, 18.390625]
# CNN made 512 moves. Successful were 19

# %%
Online_CNN.fit(x=s_before, y=actual_values, epochs=10, verbose=2)

# %%
actual_values

# %%
rewards

# %%
np.where(dones, rewards, rewards + GAMMA*rewards_next)

# %%
Online_CNN.predict(np.expand_dims(s_before[0], axis=0))

# %%
# tensorboard --logdir=./logs --bind_all &

print(MAXIMUM_SCORE)

# %% [markdown]
# ## Debuggin the Hint

# %%
# Total score of one move
reward = 0

# Whether CNN made the move
cnn_made_move_flag = False

# If replay_memory has less than 64 moves, then make a random move
if ((len(replay_memory) < MINIBATCH_SIZE) or (rd.random() > CNN_MOVE_PROB)):
    move = rd.randint(1, ae.ACTIONS_DIMENSION)
else:
    # CNN selects a move
    cnn_made_move_flag = True
    CNN_MOVES_COUNT = CNN_MOVES_COUNT + 1
    scr, move = ae.predict_max_score_3D(field.copy(), Target_CNN, ae.ACTIONS_DIMENSION, ae.MOVES)
    print(f"Predicted move {move} with score of {scr}")

# %%
# Make the move
new_field, plate_a, plate_b = ae.make_move_v2_3D(field.copy(), move, ae.MOVES)
field_after_move = new_field.copy()

# Calculate the score and update the field
score, new_field = ae.calculate_score_v2_3D(new_field, plate_a, plate_b)

# If the move is successful, then update the field and check if we have new sets        
successful_move_flag = False

# While we have new sets (thus the score is greater than 0), process them, calculate score and move plates
while (score > 0.):
    if (not successful_move_flag):
        successful_moves = successful_moves + 1
        successful_move_flag = True

    # Add new points to the total score of the move
    reward = reward + score

    # Move plates downward, fill the upper row so, that it doesn't have "easy" sets of three
    # Start from the left lower corner (in order to reuse color_fits())
    new_field = ae.fill_field_3D(new_field)

    # Calculate score and check whether we have new sets
    score, new_field = ae.calculate_score_v2_3D(new_field, (-1, -1), (-1, -1))

print(reward)

# %%
#
# Train CNN based on the score
#

samples = replay_memory.sample_minibatch(MINIBATCH_SIZE)

# Prepare some things for training
s_before = samples[0]
actions = samples[1]
rewards = samples[2]
s_after = samples[3] 
dones = samples[4]

# %%
def loss(model, X, y_true, A):
    prediction = model(X)
    selected_action_values = tf.math.reduce_sum(prediction*A, axis=1)  
    return tf.keras.losses.MSE(y_true, selected_action_values)


def grad(model, inputs, targets, actions):
    with tf.GradientTape() as tape:
        loss_value = loss(model, inputs, targets, actions)
    return loss_value, tape.gradient(loss_value, model.trainable_variables)

# %%
rewards_next = np.max(Target_CNN(s_after), axis=1)
actual_values = np.where(dones, rewards, rewards + GAMMA*rewards_next)
selected_actions = tf.one_hot(actions, ae.ACTIONS_DIMENSION)

# %%
loss_value, grads = grad(Online_CNN, s_before, actual_values, selected_actions)

print("Step: {}, Initial Loss: {}".format(optimizer.iterations.numpy(), loss_value.numpy()))

optimizer.apply_gradients(zip(grads, Online_CNN.trainable_variables))

print("Step: {}, Loss: {}".format(optimizer.iterations.numpy(), loss(Online_CNN, s_before, actual_values, selected_actions).numpy()))

# %% [markdown]
# ### Now the CNN has been trained.
# ### Start the long reinforcement-learning cycle

# %%
successful_moves

# %%
new_field = make_move(field, move)
print(new_field)

# %%
temp_field = calculate_score(new_field)

# %%
new_field = np.multiply(new_field, 1.0 - temp_field)

# %%
fill_field(new_field, colors)

# %%
#
# Save model
#
# v1: 20190329, trained on len(replay_memory) = 294912
#aero_cnn.save("Aero_CNN_v1")

# %% [markdown]
# ## Backup

# %%
#
# Create the moves dictionary
#
moves = {}

for i in range(1, 143):
    old_row, old_column, old_direction = process_move_142(i)
    
    start_row = old_row - 1
    start_col = old_column - 1
    
    if (old_direction == "down"):
        end_row = start_row + 1
        end_col = start_col
    elif (old_direction == "up"):
        end_row = start_row - 1
        end_col = start_col
    elif (old_direction == "right"):
        end_row = start_row
        end_col = start_col + 1
    else:
        end_row = start_row
        end_col = start_col - 1
        
    moves[i] = ((start_row, start_col), (end_row, end_col))
    
print(moves)
