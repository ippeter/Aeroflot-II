# %% [markdown]
# ### Use bonus plates (length of 4)

# %%
import pandas as pd
import random as rd
import numpy as np
#import qgrid

import tensorflow as tf

from collections import deque

from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.models import Model, load_model, Sequential
from keras.optimizers import Adam
#from keras.callbacks import TensorBoard

#import matplotlib.pyplot as plt
#import matplotlib.patches as mpatches
#%pylab inline

# %%
#
# Definitions
#
# RED = 0.2
# GREEN = 0.4
# BLUE = 0.6
# PURPLE = 0.8
#
colors = [0.2, 0.4, 0.6, 0.8]

moves = {1: ((0, 0), (1, 0)), 2: ((0, 1), (1, 1)), 3: ((0, 2), (1, 2)), 4: ((0, 3), (1, 3)), 5: ((0, 4), (1, 4)), 
         6: ((0, 5), (1, 5)), 7: ((1, 0), (2, 0)), 8: ((1, 0), (0, 0)), 9: ((1, 1), (2, 1)), 10: ((1, 1), (0, 1)), 
         11: ((1, 2), (2, 2)), 12: ((1, 2), (0, 2)), 13: ((1, 3), (2, 3)), 14: ((1, 3), (0, 3)), 15: ((1, 4), (2, 4)), 
         16: ((1, 4), (0, 4)), 17: ((1, 5), (2, 5)), 18: ((1, 5), (0, 5)), 19: ((2, 0), (3, 0)), 20: ((2, 0), (1, 0)), 
         21: ((2, 1), (3, 1)), 22: ((2, 1), (1, 1)), 23: ((2, 2), (3, 2)), 24: ((2, 2), (1, 2)), 25: ((2, 3), (3, 3)), 
         26: ((2, 3), (1, 3)), 27: ((2, 4), (3, 4)), 28: ((2, 4), (1, 4)), 29: ((2, 5), (3, 5)), 30: ((2, 5), (1, 5)), 
         31: ((3, 0), (4, 0)), 32: ((3, 0), (2, 0)), 33: ((3, 1), (4, 1)), 34: ((3, 1), (2, 1)), 35: ((3, 2), (4, 2)), 
         36: ((3, 2), (2, 2)), 37: ((3, 3), (4, 3)), 38: ((3, 3), (2, 3)), 39: ((3, 4), (4, 4)), 40: ((3, 4), (2, 4)), 
         41: ((3, 5), (4, 5)), 42: ((3, 5), (2, 5)), 43: ((4, 0), (5, 0)), 44: ((4, 0), (3, 0)), 45: ((4, 1), (5, 1)), 
         46: ((4, 1), (3, 1)), 47: ((4, 2), (5, 2)), 48: ((4, 2), (3, 2)), 49: ((4, 3), (5, 3)), 50: ((4, 3), (3, 3)), 
         51: ((4, 4), (5, 4)), 52: ((4, 4), (3, 4)), 53: ((4, 5), (5, 5)), 54: ((4, 5), (3, 5)), 55: ((5, 0), (6, 0)), 
         56: ((5, 0), (4, 0)), 57: ((5, 1), (6, 1)), 58: ((5, 1), (4, 1)), 59: ((5, 2), (6, 2)), 60: ((5, 2), (4, 2)), 
         61: ((5, 3), (6, 3)), 62: ((5, 3), (4, 3)), 63: ((5, 4), (6, 4)), 64: ((5, 4), (4, 4)), 65: ((5, 5), (6, 5)), 
         66: ((5, 5), (4, 5)), 67: ((6, 0), (5, 0)), 68: ((6, 1), (5, 1)), 69: ((6, 2), (5, 2)), 70: ((6, 3), (5, 3)), 
         71: ((6, 4), (5, 4)), 72: ((6, 5), (5, 5)), 73: ((0, 0), (0, 1)), 74: ((1, 0), (1, 1)), 75: ((2, 0), (2, 1)), 
         76: ((3, 0), (3, 1)), 77: ((4, 0), (4, 1)), 78: ((5, 0), (5, 1)), 79: ((6, 0), (6, 1)), 80: ((0, 1), (0, 0)), 
         81: ((0, 1), (0, 2)), 82: ((1, 1), (1, 0)), 83: ((1, 1), (1, 2)), 84: ((2, 1), (2, 0)), 85: ((2, 1), (2, 2)), 
         86: ((3, 1), (3, 0)), 87: ((3, 1), (3, 2)), 88: ((4, 1), (4, 0)), 89: ((4, 1), (4, 2)), 90: ((5, 1), (5, 0)), 
         91: ((5, 1), (5, 2)), 92: ((6, 1), (6, 0)), 93: ((6, 1), (6, 2)), 94: ((0, 2), (0, 1)), 95: ((0, 2), (0, 3)), 
         96: ((1, 2), (1, 1)), 97: ((1, 2), (1, 3)), 98: ((2, 2), (2, 1)), 99: ((2, 2), (2, 3)), 100: ((3, 2), (3, 1)), 
         101: ((3, 2), (3, 3)), 102: ((4, 2), (4, 1)), 103: ((4, 2), (4, 3)), 104: ((5, 2), (5, 1)), 105: ((5, 2), (5, 3)), 
         106: ((6, 2), (6, 1)), 107: ((6, 2), (6, 3)), 108: ((0, 3), (0, 2)), 109: ((0, 3), (0, 4)), 110: ((1, 3), (1, 2)), 
         111: ((1, 3), (1, 4)), 112: ((2, 3), (2, 2)), 113: ((2, 3), (2, 4)), 114: ((3, 3), (3, 2)), 115: ((3, 3), (3, 4)), 
         116: ((4, 3), (4, 2)), 117: ((4, 3), (4, 4)), 118: ((5, 3), (5, 2)), 119: ((5, 3), (5, 4)), 120: ((6, 3), (6, 2)), 
         121: ((6, 3), (6, 4)), 122: ((0, 4), (0, 3)), 123: ((0, 4), (0, 5)), 124: ((1, 4), (1, 3)), 125: ((1, 4), (1, 5)), 
         126: ((2, 4), (2, 3)), 127: ((2, 4), (2, 5)), 128: ((3, 4), (3, 3)), 129: ((3, 4), (3, 5)), 130: ((4, 4), (4, 3)), 
         131: ((4, 4), (4, 5)), 132: ((5, 4), (5, 3)), 133: ((5, 4), (5, 5)), 134: ((6, 4), (6, 3)), 135: ((6, 4), (6, 5)), 
         136: ((0, 5), (0, 4)), 137: ((1, 5), (1, 4)), 138: ((2, 5), (2, 4)), 139: ((3, 5), (3, 4)), 140: ((4, 5), (4, 4)), 
         141: ((5, 5), (5, 4)), 142: ((6, 5), (6, 4))}

# %% [markdown]
# ## Constants

# %%
# CNN
LEARNING_RATE = 0.01
UPDATE_TARGET_NET = 1000

# Definitions
GAMES_TO_PLAY = 120001
REPLAY_MEMORY_SIZE = 131072
DYNAMIC_LEARNING_EPOCHS = 2
MINIBATCH_SIZE = 64
NUMBER_OF_MOVES_IN_GAME = 50
GAMMA = 0.99
NUMBER_OF_STEPS = 2

# Variables
MAXIMUM_SCORE = 0
TOTAL_SCORE_100 = 0.0
AVG_SCORE_HIST = []
TOTAL_SUCCESSFUL_MOVES_100 = 0.0
AVG_SUCC_MOVES_HIST = []
CNN_MOVE_PROB = 0.1
CNN_MOVES_COUNT = 0
CNN_SUCCESSFUL_PREDICTION = 0

# %% [markdown]
# ## Functions

# %%
def color_fits(field, i, j, new_color):
    """
    Checks if two items to the left or two colors to the top are NOT of the same color as the new item.
    Input:
    - field: battfield, numpy array
    - i, j: position on the new item, int, within field.shape
    - new_color: color of the new item, float
    Output:
    - boolean: True, if the new item is ok
    """
    # Check two colors to the left
    if (j > 1):
        if (round(field[i, j - 2] % 1.0, 1) == new_color) and (round(field[i, j - 1] % 1.0, 1) == new_color):
            return False
        
    # Check two colors to the right
    if (j < 4):
        if (round(field[i, j + 2] % 1.0, 1) == new_color) and (round(field[i, j + 1] % 1.0, 1) == new_color):
            return False
    
    # Check two color to the top
    if (i < 5):
        if (round(field[i + 2, j] % 1.0, 1) == new_color) and (round(field[i + 1, j] % 1.0, 1) == new_color):
            return False
    
    return True

# %%
def initialize_field(field):
    """
    Initialization of the battle field.
    Move from bottom left corner and add new elements.
    Input: 
    - field: numpy array of zeros, 7x6
    Output:
    - field: numpy array of floats, 7x6
    """
    colors = [0.2, 0.4, 0.6, 0.8]
    
    for i in list(range(field.shape[0]))[::-1]:
        for j in range(field.shape[1]):
            rd.seed()
            new_color = rd.choice(colors)
            
            while not color_fits(field, i, j, new_color):
                rd.seed()
                new_color = rd.choice(colors)
                
            field[i, j] = new_color
    
    return field

# %%
def visualize_field(field):
    """
    Visualizes the battle field in colored circles
    Handles bonus plates
    Input:
    - field: numpy array of floats, 7x6
    Output:
    - None
    """
    fig, ax = plt.subplots(figsize=(5, 7))

    ax.set_xlim((0, 10))
    ax.set_ylim((0, 13))

    circles = []

    for ii in range(7):
        for jj in range(6):
            if (round(field[ii, jj] % 1.0, 1) == 0.2):
                clr = "red"
            elif (round(field[ii, jj] % 1.0, 1) == 0.4):
                clr = "lightgreen"
            elif (round(field[ii, jj] % 1.0, 1) == 0.6):
                clr = "cyan"
            else:
                clr = "purple"

            #if (field[ii, jj] // 1 == 1.0):
            #    circles.append( mpatches.RegularPolygon((jj + 1, 7 - ii), numVertices=4, radius=0.4, color=clr) )
            #else:
            #    circles.append( mpatches.Circle((jj + 1, 7 - ii), radius=0.4, color=clr) )
             
            #
            # DEBUG
            #
            if (field[ii, jj] == 0.0):
                circles.append( mpatches.RegularPolygon((jj + 1, 7 - ii), numVertices=3, radius=0.2, color="black") )
            elif (field[ii, jj] // 1 == 1.0):
                circles.append( mpatches.RegularPolygon((jj + 1, 7 - ii), numVertices=4, radius=0.4, color=clr) )
            else:
                circles.append( mpatches.Circle((jj + 1, 7 - ii), radius=0.4, color=clr) )


    for circ in circles:
        ax.add_artist(circ)
        
    return

# %%
def plate_in_set(plate, row, col, length, direction):
    """
    Checks whether plate is with the set given by row, col, length, direction
    Input:
    - plate: plate location, tuple (row, column)
    - row: row where the set starts
    - col: column where the set starts
    - length: the set's length
    - direction: the set's direction
    Output:
    - True if the plate is within the set, False otherwise
    """
    if (direction == 0):
        # Horizontal set
        if ((plate[0] != row) or (plate[1] < col) or (plate[1] > (col + length - 1))):
            return False
    else:
        # Vertucal set
        if ((plate[1] != col) or (plate[0] < row) or (plate[0] > (row + length - 1))):
            return False
        
    return True

# %%
def fill_field(field, colors):
    """
    Наполняет поле после сжигания рядов.
    Сдвигает фишки вниз, заполняя верхний ряд каждый раз так, чтобы верхний ряд не создавал халявной тройки
    Начинает с левого нижнего угла, чтобы переиспользовать color_fits()
    Input:
    - field: numpy array of floats, 7x6
    - colors: list of 4 floats - color values, see the definition above
    Output:
    - numpy array of floats, 7x6 - updated field
    """
    for ii in list(range(7))[::-1]:
        for jj in range(6):
            while (field[ii, jj] == 0.):
                # Опускаем на один вниз
                # Если мы в самом верхнем ряду, то опускать не нужно
                if (ii != 0):
                    for iii in list(range(1, ii + 1))[::-1]:
                        field[iii, jj] = field[iii - 1, jj]

                # Заполняем верх
                new_color = rd.choice(colors)

                while not color_fits(field, 0, jj, new_color):
                    new_color = rd.choice(colors)

                field[0, jj] = new_color  
                
    return field

# %%
def make_move_v2(field, move, moves):
    """
    Physically moves plates according to the move
    Input:
    - field: numpy array of floats, 7x6
    - move: particular move to make, 1<=move<=142
    - moves: dictionary of all possible moves defined above
    Output:
    - new_field: updated field with two swapped plates
    - plate_start: coordinates of the plate that started the move, tuple (row, column)
    - plate_end: cooredinates of the plate that ended the move, tuple (row, column)
    """
    (start_row, start_col), (end_row, end_col) = moves[move]

    # Swap two plates and create new (modified) field
    new_field = np.array(field)
    temp_color = field[end_row, end_col]
    new_field[end_row, end_col] = field[start_row, start_col]
    new_field[start_row, start_col] = temp_color
        
    return new_field, (start_row, start_col), (end_row, end_col)

# %%
def get_sets(field):
    """
    Finds all sets and all bonus plates included into those sets
    Input:
    - field: numpy array of floats, 7x6
    Output:
    - list of sets coordinates: list of tuples (row_start, column_start, set_length, direction, color), counting from top left corner
      Direction is either 0 (horizontal) or 1 (vertical)
    - list of bonus plates included into sets: list of tuples (row, column, type). 
      Type is either 4 or 5 (reserved for future)
    """
    perm_bonus_plates = []
    perm_sets = []

    # Find all 3+ sets in horizontal row
    for ii in range(field.shape[0]):
        temp_bonus_plates = []
        jj = 0
        len = 1
        while (jj < field.shape[1]):
            if (jj > 0):
                if (round(field[ii, jj] % 1.0, 1) == round(field[ii, jj - 1] % 1.0, 1)):
                    len = len + 1
                else:
                    if (len >= 3):
                        # Add temp list of bonus plates to the permanent list of bonus plates
                        perm_bonus_plates = perm_bonus_plates + temp_bonus_plates
                        
                        # Add to permanent list of sets
                        perm_sets.append((ii, jj - len, len, 0, round(field[ii, jj - 1] % 1, 1)))
                        
                    temp_bonus_plates = []
                    len = 1
            
            if (field[ii, jj] > 1.):
                # Add to temp list of bonus plates
                temp_bonus_plates.append((ii, jj, 4))
            
            jj = jj + 1
            
        if (len >= 3):
            # Add temp list of bonus plates to the permanent list of bonus plates
            perm_bonus_plates = perm_bonus_plates + temp_bonus_plates

            # Add to permanent list of sets
            perm_sets.append((ii, jj - len, len, 0, round(field[ii, jj - 1] % 1, 1)))

    # Find all 3+ sets in vertical columns
    for jj in range(field.shape[1]):
        temp_bonus_plates = []
        ii = 0
        len = 1
        while (ii < field.shape[0]):
            if (ii > 0):
                if (round(field[ii, jj] % 1.0, 1) == round(field[ii - 1, jj] % 1, 1)):
                    len = len + 1
                else:
                    if (len >= 3):
                        # Add temp list of bonus plates to the permanent list of bonus plates
                        perm_bonus_plates = perm_bonus_plates + temp_bonus_plates
                        
                        # Add to permanent list of sets
                        perm_sets.append((ii - len, jj, len, 1, round(field[ii - 1, jj] % 1, 1)))
                        
                    temp_bonus_plates = []
                    len = 1
            
            if (field[ii, jj] > 1.):
                # Add to temp list of bonus plates
                temp_bonus_plates.append((ii, jj, 4))
            
            ii = ii + 1
            
        if (len >= 3):
            # Add temp list of bonus plates to the permanent list of bonus plates
            perm_bonus_plates = perm_bonus_plates + temp_bonus_plates

            # Add to permanent list of sets
            perm_sets.append((ii - len, jj, len, 1, round(field[ii - 1, jj] % 1, 1)))
            
    return perm_sets, perm_bonus_plates

# %%
def calculate_score_v2(field, plate_from, plate_to):
    """
    Calculates the score in the field. 
    Replaces all sets with zeros.
    Handles bonus plates: replaces required rows with zeros (Type 4)
    Puts bonus plates, should any set be of the length of 4
    Input:
    - field: numpy array of floats, 7x6
    - plate_from: coordinates of the plate where the move starts, tuple (row, column)
    - plate_to: coordinates of the plate where the move ends, tuple (row, column)
    Output:
    - score: int, 0+
    - field: modified field
    """
    # Get all sets with possible bonus plates
    sets, bonus_plates = get_sets(field)

    # Set all requires plates to zero
    #
    # First handle sets
    for st in sets:
        row = st[0]
        col = st[1]
        lng = st[2]
        drc = st[3]

        if (drc == 0):
            field[row, col:(col + lng)] = 0
        else:
            field[row:(row + lng), col] = 0
    #       
    # Then handle bonus plates/rows
    for pl in bonus_plates:
        row = pl[0]
        col = pl[1]
        typ = pl[2]

        if (typ == 4):
            field[row, :] = 0

    # Calculate score
    score = (field == 0.).sum()

    # Put new bonus plates. Specially care for the move coordinates
    for st in sets:
        row = st[0]
        col = st[1]
        lng = st[2]
        drc = st[3]
        clr = st[4]

        if (lng >= 4):
            if (plate_in_set(plate_from, row, col, lng, drc)):
                # Move start plate in set. Put new bonus plate according to the move coordinates
                field[plate_from[0], plate_from[1]] = clr + 1.0
                
                #
                # DEBUG
                #
                #print("DEBUG: set of 4+ was made!")
                
            elif (plate_in_set(plate_to, row, col, lng, drc)):
                # Move end plate in set. Put new bonus plate according to the move coordinates
                field[plate_to[0], plate_to[1]] = clr + 1.0
                
                #
                # DEBUG
                #
                #print("DEBUG: set of 4+ was made!")
                
            else:
                # Just put the new bonus plate at the very right/bottom of the set
                # This CANNOT happen during the manual move!
                # It CAN ONLY HAPPEN when the field is randomly filled with new plates
                if (drc == 0):
                    field[row, col + lng - 1] = clr + 1.0
                else:
                    field[row + lng - 1, col] = clr + 1.0

    return score, field

# %%
def predict_max_score(field, aero_cnn, number_of_moves, moves, debug_flag = False):
    """
    TODO 
    """
    X_data = ()
           
    for move in range(1, number_of_moves + 1):
        swapped, _, _ = make_move_v2(np.array(field), move, moves)
        X_data = X_data + ( swapped, )
    
    # Теперь выбираем наиболее успешый ход из всех успешных
    X_data = np.expand_dims(np.stack(X_data, axis=0), axis=3)
    
    prediction = aero_cnn.predict(X_data)
    
    if (debug_flag):
        print("DEBUG", prediction)
    
    best_move_score = prediction.max()
    best_move_number = prediction.argmax() + 1
    
    return best_move_score, best_move_number

# %% [markdown]
# ### Replay Memory Buffer

# %%
#
# Replay memory buffer
#
class MultiStepExperienceBuffer():
    '''
    Experience Replay Buffer for multi-step learning
    Inspired by Andrea Lonza
    '''

    def __init__(self, buffer_size, n_step, gamma):
        # Constants
        self.n_step = n_step
        self.gamma = gamma
        
        # Main Replay Memory buffer parts
        self.states_before = deque(maxlen=buffer_size)
        self.actions = deque(maxlen=buffer_size)
        self.total_rewards = deque(maxlen=buffer_size)
        self.states_after = deque(maxlen=buffer_size)
        self.last_moves = deque(maxlen=buffer_size)
        
        # Helper buffer to keep last n_step rewards
        self.last_rewards = deque(maxlen=self.n_step + 1)
   
    
    def add(self, state_before, action, reward, state_after, last_move):
        # Add certain items to corresponding buffers
        self.states_before.append(state_before)
        self.actions.append(action)
        # Other items are not known at this point, so add None
        self.total_rewards.append(None)
        self.states_after.append(None)
        self.last_moves.append(None)
        
        # Add current reward to dedicated sliding window of rewards
        self.last_rewards.append(reward)
        
        if (last_move):            
            for i in range(self.n_step + 1):
                self.states_after[-self.n_step - 1 + i] = state_after                
                self.last_moves[-self.n_step - 1 + i] = last_move
                
                total_reward = np.sum([(self.gamma**k)*r for k, r in enumerate(np.array(self.last_rewards)[i:])])
                self.total_rewards[-self.n_step - 1 + i] = total_reward

            # Reset the reward deque
            self.last_rewards = deque(maxlen=self.n_step + 1)
        else:
            if (len(self.last_rewards) == (self.n_step + 1)):
                self.states_after[-self.n_step - 1] = state_after
                self.last_moves[-self.n_step - 1] = last_move
                
                total_reward = np.sum([(self.gamma**k)*r for k, r in enumerate(np.array(self.last_rewards))])
                self.total_rewards[-self.n_step - 1] = total_reward
    
    
    def sample_minibatch(self, minibatch_size):
        '''
        Sample a minibatch of size batch_size
        Note1: the samples should be at least of n_step steps ago
        Note2: always add the most recent completed move
        '''
        indices = rd.sample(range(len(self.states_before) - self.n_step - 1), minibatch_size - 1)
        # Add the most recent completed move index
        indices.append(len(self.states_before) - self.n_step - 1)
        
        minibatch_states_before = np.array([self.states_before[i] for i in indices]) 
        minibatch_actions = np.array([self.actions[i] for i in indices]) 
        minibatch_total_rewards = np.array([self.total_rewards[i] for i in indices]) 
        minibatch_states_after = np.array([self.states_after[i] for i in indices])  
        minibatch_last_moves = np.array([self.last_moves[i] for i in indices])   
        
        return minibatch_states_before, minibatch_actions, minibatch_total_rewards, minibatch_states_after, minibatch_last_moves
    
    
    def __len__(self):
        '''
        Return length of the current replay memory buffer
        Relevant for the first *minibatch_size* moves.
        '''
        return len(self.states_before)

# %% [markdown]
# ### Deep Q-Nework

# %%
class AeroCNN(tf.keras.Model):

    def __init__(self):
        super(AeroCNN, self).__init__()
        
        self.gamma = GAMMA
        self.learning_rate = LEARNING_RATE
        
        self.optimizer = Adam(learning_rate=self.learning_rate)      
        
        self.input_layer = tf.keras.layers.InputLayer(input_shape=(7, 6, 1))
        
        self.hidden_layers = [] 
        self.hidden_layers.append(Conv2D(128, kernel_size=3, strides = (1, 1), padding='same', activation='relu', data_format = 'channels_last'))
        self.hidden_layers.append(Conv2D(64, kernel_size=3, strides = (1, 1), padding='same', activation='relu'))    
        self.hidden_layers.append(Flatten())                      
                                  
        self.output_layer = tf.keras.layers.Dense(142, activation='relu', kernel_initializer='RandomNormal')

                                  
    # Define model forward pass
    #@tf.function
    def call(self, inputs):
        
        z = self.input_layer(inputs)
                                  
        for layer in self.hidden_layers:
            z = layer(z)
                                  
        output = self.output_layer(z)
                                  
        return output
                   
        
    def train(self, s_before, actions, rewards, s_after, dones, TargetNet):
        
        rewards_next = np.max(TargetNet.predict(s_after), axis=1)
        actual_values = np.where(dones, rewards, rewards + self.gamma*rewards_next)
        
        with tf.GradientTape() as tape:
            prediction = self.call(s_before)
            
            selected_action_values = tf.math.reduce_sum(prediction*tf.one_hot(actions, 142), axis=1)  
            
            loss = tf.math.reduce_mean(tf.square(actual_values - selected_action_values))
            
        gradients = tape.gradient(loss, self.trainable_weights)
        
        self.optimizer.apply_gradients(zip(gradients, self.trainable_weights))
        
        return loss

# %% [markdown]
# ### Initialize Replay Buffer

# %%
replay_memory = MultiStepExperienceBuffer(REPLAY_MEMORY_SIZE, NUMBER_OF_STEPS, GAMMA)

# %% [markdown]
# ### Initialize Online CNN and Target CNN

# %%
cnn_online = AeroCNN()  
cnn_target = AeroCNN()

cnn_target.set_weights(cnn_online.get_weights())

# %% [markdown]
# ### Collect some data to test new data model

# %%
# %%time

# Number of moves made to follow the target CNN update strategy
total_moves = 1
                                                      
for game in range(10):
    # Start one game
    game_score = 0
    successful_moves = 0

    # Initialize the game field
    field = np.zeros((7, 6))
    field = initialize_field(field)

    for m in range(NUMBER_OF_MOVES_IN_GAME):
        # Total score of one move
        reward = 0

        # Whether CNN made the move
        cnn_made_move_flag = False
        
        # Make random move
        move = rd.randint(1, 142)

        # Make the move
        s_before = field
        new_field, plate_a, plate_b = make_move_v2(field, move, moves)

        # Calculate the score and update the field
        score, new_field = calculate_score_v2(new_field, plate_a, plate_b)
        
        # Если ход результативный, то обновляем поле и проверяем, получились ли новые цветовые ряды
        # Пока есть новые цветные ряды, обрабатываем их, обсчитываем и сдвигаем блюда
        successful_move_flag = False

        while (score > 0.):
            if (not successful_move_flag):
                successful_moves = successful_moves + 1
                successful_move_flag = True

            # Суммируем набранные очки
            reward = reward + score

            # Сдвигаем фишки вниз, заполняя верхний ряд каждый раз так, чтобы верхний ряд не создавал халявной тройки
            # Начинаем с левого нижнего угла (чтобы переиспользовать color_fits())
            new_field = fill_field(new_field, colors)

            # Считаем очки и обрабатываем новые возможные цветные ряды
            score, new_field = calculate_score_v2(new_field, (-1, -1), (-1, -1))

        # Увеличиваем счет игры
        game_score = game_score + reward
        
        # Update CNN move statistics
        if (cnn_made_move_flag):
            if (successful_move_flag):
                CNN_SUCCESSFUL_PREDICTION = CNN_SUCCESSFUL_PREDICTION + 1
                
            CNN_MOVES_COUNT = CNN_MOVES_COUNT + 1
            
        # Check whether it's the last move of the current game
        last_move = m == NUMBER_OF_MOVES_IN_GAME - 1
            
        # Add new move to the replay memory
        replay_memory.add(field, move, reward, new_field, last_move)
        
        # If move is successful, update the play field
        if (successful_move_flag):
            field = new_field
            
        total_moves = total_moves + 1

# %%
len(replay_memory)

# %%
samples = replay_memory.sample_minibatch(MINIBATCH_SIZE)

# %% [markdown]
# ## Dynamic Learning

# %%
# %%time

# Number of moves made to follow the target CNN update strategy
total_moves = 1
                                                      
for game in range(GAMES_TO_PLAY):
    # Start one game
    game_score = 0
    successful_moves = 0

    # Initialize the game field
    field = np.zeros((7, 6))
    field = initialize_field(field)

    for m in range(NUMBER_OF_MOVES_IN_GAME):
        # Total score of one move
        reward = 0

        # Whether CNN made the move
        cnn_made_move_flag = False
        
        # If replay_memory has less than MINIBATCH_SIZE + NUMBER_OF_STEPS moves, then make a random move
        if ((len(replay_memory) < MINIBATCH_SIZE + NUMBER_OF_STEPS) or (rd.random() > CNN_MOVE_PROB)):
            move = rd.randint(1, 142)
        else:
            # CNN selects a move
            cnn_made_move_flag = True
            X_data = np.expand_dims(np.expand_dims(field, axis=0), axis=3)
            move = cnn_target.predict(X_data).argmax() + 1
            
        # Make the move
        s_before = field
        new_field, plate_a, plate_b = make_move_v2(field, move, moves)

        # Calculate the score and update the field
        score, new_field = calculate_score_v2(new_field, plate_a, plate_b)
        
        # Если ход результативный, то обновляем поле и проверяем, получились ли новые цветовые ряды
        # Пока есть новые цветные ряды, обрабатываем их, обсчитываем и сдвигаем блюда
        successful_move_flag = False

        while (score > 0.):
            if (not successful_move_flag):
                successful_moves = successful_moves + 1
                successful_move_flag = True

            # Суммируем набранные очки
            reward = reward + score

            # Сдвигаем фишки вниз, заполняя верхний ряд каждый раз так, чтобы верхний ряд не создавал халявной тройки
            # Начинаем с левого нижнего угла (чтобы переиспользовать color_fits())
            new_field = fill_field(new_field, colors)

            # Считаем очки и обрабатываем новые возможные цветные ряды
            score, new_field = calculate_score_v2(new_field, (-1, -1), (-1, -1))

        # Увеличиваем счет игры
        game_score = game_score + reward
        
        # Update CNN move statistics
        if (cnn_made_move_flag):
            if (successful_move_flag):
                CNN_SUCCESSFUL_PREDICTION = CNN_SUCCESSFUL_PREDICTION + 1
                
            CNN_MOVES_COUNT = CNN_MOVES_COUNT + 1
            
        # Check whether it's the last move of the current game
        last_move = m == NUMBER_OF_MOVES_IN_GAME - 1
            
        #
        # Train CNN based on the score
        #
        if (len(replay_memory) >= MINIBATCH_SIZE + NUMBER_OF_STEPS):
            # Select random MINIBATCH_SIZE moves from replay memory buffer
            samples = replay_memory.sample_minibatch(MINIBATCH_SIZE)

            # Prepare some things for training
            S_before = np.expand_dims(samples[0], axis=3)
            S_after = np.expand_dims(samples[3], axis=3)            

            # Update online CNN weights: training step
            loss = cnn_online.train(S_before, samples[1], samples[2], S_after, samples[4], cnn_target)
        
        # Add new move to the replay memory
        replay_memory.add(field, move, reward, new_field, last_move)
        
        # If move is successful, update the play field
        if (successful_move_flag):
            field = new_field
            
        # After each 1000 moves update target CNN
        if (total_moves % UPDATE_TARGET_NET == 0):
            cnn_target.set_weights(cnn_online.get_weights())
            
        total_moves = total_moves + 1

    #
    # Calculate and display overall stats
    #
    # Проверяем, не обновили ли максимум
    if (game_score > MAXIMUM_SCORE):
        print(f"New maximum: {game_score}, after {game} games.")
        MAXIMUM_SCORE = game_score
        
    # After each hundred of games output average game score, average number of successful moves per game
    TOTAL_SCORE_100 = TOTAL_SCORE_100 + game_score
    TOTAL_SUCCESSFUL_MOVES_100 = TOTAL_SUCCESSFUL_MOVES_100 + successful_moves
    
    if ((game % 500 == 0) and (game > 0)):
        avg_score = TOTAL_SCORE_100 / 500
        #AVG_SCORE_HIST.append(avg_score)
        TOTAL_SCORE_100 = 0.0
        
        avg_succ_moves = TOTAL_SUCCESSFUL_MOVES_100 / 500
        #AVG_SUCC_MOVES_HIST.append(avg_succ_moves)
        TOTAL_SUCCESSFUL_MOVES_100 = 0.0

        print(f"Games: {game}, last 500 games avg score: {avg_score}, avg of successful moves: {avg_succ_moves}, loss {loss}")        

        print(f"CNN made {CNN_MOVES_COUNT} moves. Successful were {CNN_SUCCESSFUL_PREDICTION}")
        
        if (CNN_SUCCESSFUL_PREDICTION / CNN_MOVES_COUNT >= CNN_MOVE_PROB):
            CNN_MOVE_PROB = CNN_MOVE_PROB + 0.1
            
        CNN_MOVES_COUNT = 0
        CNN_SUCCESSFUL_PREDICTION = 0

    # After each 500 games check the CNN move stats and increase the prob if appropriate
    #if ((game % 100 == 0) and (game > 0)):
# Out:
# Games: 500, last 500 games avg score: 56.158, avg of successful moves: 8.498, loss 207163351891968.0
# CNN made 5145 moves. Successful were 529
# Games: 1000, last 500 games avg score: 58.128, avg of successful moves: 8.854, loss 974948449386496.0
# CNN made 4940 moves. Successful were 529
# Games: 1500, last 500 games avg score: 57.284, avg of successful moves: 8.83, loss 292418419163136.0
# CNN made 4970 moves. Successful were 526
# Games: 2000, last 500 games avg score: 59.592, avg of successful moves: 9.048, loss 306270292672512.0
# CNN made 5005 moves. Successful were 539
# Games: 2500, last 500 games avg score: 57.338, avg of successful moves: 8.68, loss 357927273627648.0
# CNN made 4976 moves. Successful were 504
# Games: 3000, last 500 games avg score: 59.42, avg of successful moves: 8.788, loss 286230679912448.0
# CNN made 4900 moves. Successful were 511
# Games: 3500, last 500 games avg score: 58.418, avg of successful moves: 8.824, loss 540987705262080.0
# CNN made 4953 moves. Successful were 503
# Games: 4000, last 500 games avg score: 59.962, avg of successful moves: 8.818, loss 438444153110528.0
# CNN made 4963 moves. Successful were 559
# Games: 4500, last 500 games avg score: 57.78, avg of successful moves: 8.89, loss 423329559216128.0
# CNN made 4957 moves. Successful were 543
# Games: 5000, last 500 games avg score: 59.88, avg of successful moves: 8.978, loss 604185062014976.0
# CNN made 5099 moves. Successful were 535
# Games: 5500, last 500 games avg score: 58.268, avg of successful moves: 8.748, loss 294848565346304.0
# CNN made 4948 moves. Successful were 509
# Games: 6000, last 500 games avg score: 58.476, avg of successful moves: 8.752, loss 344497716199424.0
# CNN made 4997 moves. Successful were 521
# Games: 6500, last 500 games avg score: 58.514, avg of successful moves: 8.836, loss 308976491167744.0
# CNN made 5004 moves. Successful were 510
# Games: 7000, last 500 games avg score: 59.848, avg of successful moves: 9.076, loss 336549476564992.0
# CNN made 4883 moves. Successful were 500
# Games: 7500, last 500 games avg score: 60.13, avg of successful moves: 8.888, loss 288055940349952.0
# CNN made 4809 moves. Successful were 504
# Games: 8000, last 500 games avg score: 59.144, avg of successful moves: 8.774, loss 201408599031808.0
# CNN made 5053 moves. Successful were 539
# Games: 8500, last 500 games avg score: 57.044, avg of successful moves: 8.672, loss 286302654169088.0
# CNN made 5154 moves. Successful were 494
# Games: 9000, last 500 games avg score: 58.052, avg of successful moves: 8.854, loss 292069385961472.0
# CNN made 5045 moves. Successful were 499
# Games: 9500, last 500 games avg score: 56.768, avg of successful moves: 8.674, loss 312731903197184.0
# CNN made 5036 moves. Successful were 501
# Games: 10000, last 500 games avg score: 56.548, avg of successful moves: 8.646, loss 862035973767168.0
# CNN made 5109 moves. Successful were 470
# Games: 10500, last 500 games avg score: 58.044, avg of successful moves: 8.91, loss 2233185425424384.0
# CNN made 5002 moves. Successful were 502
# Games: 11000, last 500 games avg score: 57.41, avg of successful moves: 8.596, loss 401891766829056.0
# CNN made 4902 moves. Successful were 478
# Games: 11500, last 500 games avg score: 58.346, avg of successful moves: 8.884, loss 494156052955136.0
# CNN made 5005 moves. Successful were 524
# Games: 12000, last 500 games avg score: 59.658, avg of successful moves: 9.0, loss 1906389014282240.0
# CNN made 5035 moves. Successful were 552
# Games: 12500, last 500 games avg score: 61.516, avg of successful moves: 8.952, loss 404475827191808.0
# CNN made 5028 moves. Successful were 539
# Games: 13000, last 500 games avg score: 59.442, avg of successful moves: 8.84, loss 834453962227712.0
# CNN made 4954 moves. Successful were 525
# Games: 13500, last 500 games avg score: 61.262, avg of successful moves: 9.01, loss 375037148266496.0
# CNN made 4939 moves. Successful were 511
# Games: 14000, last 500 games avg score: 59.982, avg of successful moves: 8.954, loss 600531185696768.0
# CNN made 5034 moves. Successful were 572
# Games: 14500, last 500 games avg score: 60.278, avg of successful moves: 8.956, loss 691626301194240.0
# CNN made 4959 moves. Successful were 493
# Games: 15000, last 500 games avg score: 59.598, avg of successful moves: 9.018, loss 392661412347904.0
# CNN made 4992 moves. Successful were 498
# Games: 15500, last 500 games avg score: 58.382, avg of successful moves: 8.668, loss 696248357093376.0
# CNN made 5030 moves. Successful were 511
# Games: 16000, last 500 games avg score: 59.43, avg of successful moves: 8.818, loss 328915675512832.0
# CNN made 5095 moves. Successful were 511
# Games: 16500, last 500 games avg score: 57.848, avg of successful moves: 8.838, loss 642267127742464.0
# CNN made 4990 moves. Successful were 494
# Games: 17000, last 500 games avg score: 56.192, avg of successful moves: 8.486, loss 497002005659648.0
# CNN made 5033 moves. Successful were 420
# Games: 17500, last 500 games avg score: 58.026, avg of successful moves: 8.826, loss 461379647569920.0
# CNN made 5089 moves. Successful were 473
# Games: 18000, last 500 games avg score: 56.516, avg of successful moves: 8.492, loss 250257711562752.0
# CNN made 5030 moves. Successful were 454
# Games: 18500, last 500 games avg score: 58.396, avg of successful moves: 8.89, loss 625007667445760.0
# CNN made 5030 moves. Successful were 530
# Games: 19000, last 500 games avg score: 58.032, avg of successful moves: 8.83, loss 679984389685248.0
# CNN made 5051 moves. Successful were 516
# Games: 19500, last 500 games avg score: 59.184, avg of successful moves: 8.77, loss 283416402591744.0
# CNN made 4979 moves. Successful were 507
# Games: 20000, last 500 games avg score: 58.62, avg of successful moves: 8.83, loss 567471278915584.0
# CNN made 5042 moves. Successful were 482
# Games: 20500, last 500 games avg score: 57.284, avg of successful moves: 8.45, loss 413918849662976.0
# CNN made 5047 moves. Successful were 439
# Games: 21000, last 500 games avg score: 56.716, avg of successful moves: 8.726, loss 84702576771072.0
# CNN made 5035 moves. Successful were 446
# Games: 21500, last 500 games avg score: 58.054, avg of successful moves: 8.842, loss 176586187866112.0
# CNN made 5065 moves. Successful were 501
# Games: 22000, last 500 games avg score: 58.342, avg of successful moves: 8.918, loss 283776408092672.0
# CNN made 4838 moves. Successful were 479
# Games: 22500, last 500 games avg score: 56.672, avg of successful moves: 8.648, loss 347827389595648.0
# CNN made 4879 moves. Successful were 458
# Games: 23000, last 500 games avg score: 56.952, avg of successful moves: 8.606, loss 223169252163584.0
# CNN made 5016 moves. Successful were 444
# Games: 23500, last 500 games avg score: 58.138, avg of successful moves: 8.692, loss 166187551948800.0
# CNN made 5071 moves. Successful were 472
# Games: 24000, last 500 games avg score: 59.848, avg of successful moves: 9.118, loss 243387072512000.0
# CNN made 4982 moves. Successful were 521
# Games: 24500, last 500 games avg score: 54.066, avg of successful moves: 8.552, loss 251737680117760.0
# CNN made 4953 moves. Successful were 451
# Games: 25000, last 500 games avg score: 59.864, avg of successful moves: 8.722, loss 320433819746304.0
# CNN made 5033 moves. Successful were 498
# Games: 25500, last 500 games avg score: 58.084, avg of successful moves: 8.774, loss 122141999628288.0
# CNN made 5076 moves. Successful were 481
# Games: 26000, last 500 games avg score: 56.018, avg of successful moves: 8.682, loss 116000993312768.0
# CNN made 4956 moves. Successful were 459
# Games: 26500, last 500 games avg score: 58.196, avg of successful moves: 8.764, loss 94792864235520.0
# CNN made 5043 moves. Successful were 476
# Games: 27000, last 500 games avg score: 58.442, avg of successful moves: 8.858, loss 103985209933824.0
# CNN made 4996 moves. Successful were 432
# Games: 27500, last 500 games avg score: 55.938, avg of successful moves: 8.712, loss 75331478224896.0
# CNN made 5015 moves. Successful were 404
# Games: 28000, last 500 games avg score: 56.396, avg of successful moves: 8.646, loss 189554103418880.0
# CNN made 5046 moves. Successful were 422
# Games: 28500, last 500 games avg score: 57.392, avg of successful moves: 8.832, loss 160055764713472.0
# CNN made 4983 moves. Successful were 449
# Games: 29000, last 500 games avg score: 59.012, avg of successful moves: 9.008, loss 75318987587584.0
# CNN made 4905 moves. Successful were 506
# Games: 29500, last 500 games avg score: 58.664, avg of successful moves: 8.83, loss 72003583213568.0
# CNN made 5061 moves. Successful were 494
# Games: 30000, last 500 games avg score: 58.626, avg of successful moves: 8.992, loss 68895054495744.0
# CNN made 5031 moves. Successful were 497
# Games: 30500, last 500 games avg score: 57.98, avg of successful moves: 8.708, loss 31911101595648.0
# CNN made 4987 moves. Successful were 452
# Games: 31000, last 500 games avg score: 57.052, avg of successful moves: 8.626, loss 66487276535808.0
# CNN made 5062 moves. Successful were 506
# Games: 31500, last 500 games avg score: 59.06, avg of successful moves: 8.798, loss 79199649923072.0
# CNN made 4871 moves. Successful were 505
# Games: 32000, last 500 games avg score: 58.38, avg of successful moves: 8.796, loss 167387793981440.0
# CNN made 4941 moves. Successful were 474
# Games: 32500, last 500 games avg score: 56.958, avg of successful moves: 8.768, loss 124171061297152.0
# CNN made 4918 moves. Successful were 476
# Games: 33000, last 500 games avg score: 57.686, avg of successful moves: 8.754, loss 134505507586048.0
# CNN made 4987 moves. Successful were 481
# Games: 33500, last 500 games avg score: 59.786, avg of successful moves: 8.926, loss 156461665615872.0
# CNN made 4935 moves. Successful were 462
# Games: 34000, last 500 games avg score: 56.71, avg of successful moves: 8.68, loss 256514874933248.0
# CNN made 5052 moves. Successful were 454
# Games: 34500, last 500 games avg score: 57.982, avg of successful moves: 8.698, loss 122981489573888.0
# CNN made 5034 moves. Successful were 470
# Games: 35000, last 500 games avg score: 59.74, avg of successful moves: 8.964, loss 292159177621504.0
# CNN made 4929 moves. Successful were 495
# Games: 35500, last 500 games avg score: 60.016, avg of successful moves: 9.068, loss 255631168634880.0
# CNN made 4875 moves. Successful were 527
# Games: 36000, last 500 games avg score: 58.218, avg of successful moves: 8.938, loss 221711278538752.0
# CNN made 5004 moves. Successful were 590
# Games: 36500, last 500 games avg score: 58.156, avg of successful moves: 8.682, loss 244289921613824.0
# CNN made 5085 moves. Successful were 494
# Games: 37000, last 500 games avg score: 59.344, avg of successful moves: 8.932, loss 217188040441856.0
# CNN made 5074 moves. Successful were 554
# Games: 37500, last 500 games avg score: 58.86, avg of successful moves: 8.99, loss 222151630127104.0
# CNN made 5109 moves. Successful were 535
# Games: 38000, last 500 games avg score: 58.584, avg of successful moves: 8.884, loss 47617539047424.0
# CNN made 4917 moves. Successful were 494
# Games: 38500, last 500 games avg score: 58.258, avg of successful moves: 8.718, loss 62478281080832.0
# CNN made 4982 moves. Successful were 476
# Games: 39000, last 500 games avg score: 58.4, avg of successful moves: 8.746, loss 28112066707456.0
# CNN made 5009 moves. Successful were 466
# Games: 39500, last 500 games avg score: 57.202, avg of successful moves: 8.822, loss 65480366751744.0
# CNN made 5083 moves. Successful were 526
# Games: 40000, last 500 games avg score: 58.03, avg of successful moves: 8.828, loss 152836713218048.0
# CNN made 4991 moves. Successful were 528
# Games: 40500, last 500 games avg score: 60.408, avg of successful moves: 8.902, loss 299699261145088.0
# CNN made 4981 moves. Successful were 498
# Games: 41000, last 500 games avg score: 59.748, avg of successful moves: 8.986, loss 374003671760896.0
# CNN made 4965 moves. Successful were 517
# Games: 41500, last 500 games avg score: 56.576, avg of successful moves: 8.584, loss 384501242920960.0
# CNN made 5044 moves. Successful were 504
# Games: 42000, last 500 games avg score: 56.45, avg of successful moves: 8.564, loss 338488117428224.0
# CNN made 5065 moves. Successful were 453
# Games: 42500, last 500 games avg score: 58.988, avg of successful moves: 8.828, loss 1219965059334144.0
# CNN made 5122 moves. Successful were 467
# Games: 43000, last 500 games avg score: 58.778, avg of successful moves: 8.804, loss 1179705914949632.0
# CNN made 4965 moves. Successful were 511
# Games: 43500, last 500 games avg score: 59.884, avg of successful moves: 8.826, loss 1083443282706432.0
# CNN made 4910 moves. Successful were 446
# Games: 44000, last 500 games avg score: 57.302, avg of successful moves: 8.646, loss 2904715910184960.0
# CNN made 5002 moves. Successful were 440
# Games: 44500, last 500 games avg score: 56.936, avg of successful moves: 8.65, loss 789907031195648.0
# CNN made 5001 moves. Successful were 437
# Games: 45000, last 500 games avg score: 58.034, avg of successful moves: 8.834, loss 387068358295552.0
# CNN made 5061 moves. Successful were 474
# Games: 45500, last 500 games avg score: 60.446, avg of successful moves: 8.996, loss 386180575133696.0
# CNN made 4992 moves. Successful were 489
# Games: 46000, last 500 games avg score: 57.86, avg of successful moves: 8.826, loss 392228425957376.0
# CNN made 5124 moves. Successful were 468
# Games: 46500, last 500 games avg score: 57.736, avg of successful moves: 8.658, loss 243925554036736.0
# CNN made 4972 moves. Successful were 468
# Games: 47000, last 500 games avg score: 58.374, avg of successful moves: 8.712, loss 329540224155648.0
# CNN made 5051 moves. Successful were 479
# Games: 47500, last 500 games avg score: 59.748, avg of successful moves: 8.892, loss 184721929666560.0
# CNN made 4943 moves. Successful were 508
# Games: 48000, last 500 games avg score: 57.628, avg of successful moves: 8.662, loss 578523102183424.0
# CNN made 5025 moves. Successful were 425
# Games: 48500, last 500 games avg score: 59.06, avg of successful moves: 8.928, loss 757809666850816.0
# CNN made 5008 moves. Successful were 478
# Games: 49000, last 500 games avg score: 56.596, avg of successful moves: 8.828, loss 502698071818240.0
# CNN made 4975 moves. Successful were 466
# Games: 49500, last 500 games avg score: 60.824, avg of successful moves: 8.982, loss 758820393451520.0
# CNN made 4978 moves. Successful were 540
# Games: 50000, last 500 games avg score: 58.662, avg of successful moves: 8.786, loss 429154340175872.0
# CNN made 4989 moves. Successful were 470
# Games: 50500, last 500 games avg score: 60.228, avg of successful moves: 9.178, loss 855915779588096.0
# CNN made 4868 moves. Successful were 553
# Games: 51000, last 500 games avg score: 59.284, avg of successful moves: 9.068, loss 349326668726272.0
# CNN made 4934 moves. Successful were 542
# Games: 51500, last 500 games avg score: 59.754, avg of successful moves: 8.92, loss 191278633451520.0
# CNN made 5006 moves. Successful were 502
# Games: 52000, last 500 games avg score: 58.638, avg of successful moves: 8.71, loss 162808922636288.0
# CNN made 5032 moves. Successful were 513
# Games: 52500, last 500 games avg score: 59.432, avg of successful moves: 8.862, loss 265578530996224.0
# CNN made 5029 moves. Successful were 581
# Games: 53000, last 500 games avg score: 59.678, avg of successful moves: 9.068, loss 249654318989312.0
# CNN made 4834 moves. Successful were 558
# Games: 53500, last 500 games avg score: 58.402, avg of successful moves: 8.516, loss 334936447909888.0
# CNN made 5089 moves. Successful were 501
# Games: 54000, last 500 games avg score: 62.816, avg of successful moves: 9.006, loss 200444076883968.0
# CNN made 4899 moves. Successful were 525
# Games: 54500, last 500 games avg score: 60.562, avg of successful moves: 8.96, loss 154785940504576.0
# CNN made 4938 moves. Successful were 529
# Games: 55000, last 500 games avg score: 60.222, avg of successful moves: 8.94, loss 131447876747264.0
# CNN made 5006 moves. Successful were 524
# Games: 55500, last 500 games avg score: 57.652, avg of successful moves: 8.838, loss 93385658466304.0
# CNN made 4908 moves. Successful were 488
# Games: 56000, last 500 games avg score: 59.884, avg of successful moves: 8.982, loss 89651419283456.0
# CNN made 5010 moves. Successful were 583
# Games: 56500, last 500 games avg score: 61.156, avg of successful moves: 9.3, loss 156936997699584.0
# CNN made 4931 moves. Successful were 589
# Games: 57000, last 500 games avg score: 58.828, avg of successful moves: 8.958, loss 157229659455488.0
# CNN made 4946 moves. Successful were 521
# Games: 57500, last 500 games avg score: 56.594, avg of successful moves: 8.536, loss 141892062806016.0
# CNN made 5045 moves. Successful were 434
# Games: 58000, last 500 games avg score: 58.582, avg of successful moves: 8.866, loss 161837521829888.0
# CNN made 4971 moves. Successful were 484
# Games: 58500, last 500 games avg score: 57.562, avg of successful moves: 8.758, loss 132854000386048.0
# CNN made 4949 moves. Successful were 486
# Games: 59000, last 500 games avg score: 60.384, avg of successful moves: 9.126, loss 64947706920960.0
# CNN made 5002 moves. Successful were 545
# Games: 59500, last 500 games avg score: 58.766, avg of successful moves: 8.944, loss 70256559128576.0
# CNN made 5071 moves. Successful were 548
# Games: 60000, last 500 games avg score: 58.082, avg of successful moves: 8.786, loss 142061328138240.0
# CNN made 5033 moves. Successful were 506
# Games: 60500, last 500 games avg score: 56.862, avg of successful moves: 8.668, loss 272191505563648.0
# CNN made 5115 moves. Successful were 511
# Games: 61000, last 500 games avg score: 57.384, avg of successful moves: 8.692, loss 466028916113408.0
# CNN made 4964 moves. Successful were 469
# Games: 61500, last 500 games avg score: 56.282, avg of successful moves: 8.596, loss 498078733828096.0
# CNN made 5116 moves. Successful were 477
# Games: 62000, last 500 games avg score: 60.762, avg of successful moves: 9.126, loss 395095417290752.0
# CNN made 4903 moves. Successful were 511
# Games: 62500, last 500 games avg score: 57.16, avg of successful moves: 8.666, loss 339570415632384.0
# CNN made 5009 moves. Successful were 439
# Games: 63000, last 500 games avg score: 56.586, avg of successful moves: 8.59, loss 312826224705536.0
# CNN made 4996 moves. Successful were 372
# Games: 63500, last 500 games avg score: 58.048, avg of successful moves: 8.58, loss 153519646572544.0
# CNN made 5085 moves. Successful were 380
# Games: 64000, last 500 games avg score: 55.938, avg of successful moves: 8.626, loss 351847747420160.0
# CNN made 5012 moves. Successful were 393
# Games: 64500, last 500 games avg score: 57.922, avg of successful moves: 8.774, loss 491065891094528.0
# CNN made 5028 moves. Successful were 408
# Games: 65000, last 500 games avg score: 57.458, avg of successful moves: 8.776, loss 325894266683392.0
# CNN made 4987 moves. Successful were 475
# Games: 65500, last 500 games avg score: 58.66, avg of successful moves: 8.85, loss 167567377301504.0
# CNN made 5007 moves. Successful were 484
# Games: 66000, last 500 games avg score: 55.946, avg of successful moves: 8.706, loss 114191184691200.0
# CNN made 5027 moves. Successful were 460
# Games: 66500, last 500 games avg score: 56.61, avg of successful moves: 8.786, loss 97815908843520.0
# CNN made 5144 moves. Successful were 518
# Games: 67000, last 500 games avg score: 56.658, avg of successful moves: 8.722, loss 98098781093888.0
# CNN made 5045 moves. Successful were 496
# Games: 67500, last 500 games avg score: 57.892, avg of successful moves: 9.04, loss 104311535173632.0
# CNN made 5016 moves. Successful were 536
# Games: 68000, last 500 games avg score: 58.228, avg of successful moves: 8.932, loss 133621348302848.0
# CNN made 5063 moves. Successful were 513
# Games: 68500, last 500 games avg score: 56.64, avg of successful moves: 8.796, loss 81155487432704.0
# CNN made 5014 moves. Successful were 496
# Games: 69000, last 500 games avg score: 58.31, avg of successful moves: 8.91, loss 69813246361600.0
# CNN made 4825 moves. Successful were 538
# Games: 69500, last 500 games avg score: 56.912, avg of successful moves: 8.888, loss 61958782976000.0
# CNN made 4977 moves. Successful were 516
# Games: 70000, last 500 games avg score: 58.558, avg of successful moves: 8.864, loss 59682060238848.0
# CNN made 5003 moves. Successful were 538
# Games: 70500, last 500 games avg score: 58.3, avg of successful moves: 8.918, loss 35865459949568.0
# CNN made 4986 moves. Successful were 473
# Games: 71000, last 500 games avg score: 57.092, avg of successful moves: 8.768, loss 31199175114752.0
# CNN made 5092 moves. Successful were 492
# Games: 71500, last 500 games avg score: 56.708, avg of successful moves: 8.822, loss 42323585007616.0
# CNN made 5028 moves. Successful were 493
# Games: 72000, last 500 games avg score: 57.268, avg of successful moves: 8.668, loss 116528015998976.0
# CNN made 5074 moves. Successful were 502
# Games: 72500, last 500 games avg score: 58.706, avg of successful moves: 8.956, loss 782064488022016.0
# CNN made 4961 moves. Successful were 514
# Games: 73000, last 500 games avg score: 57.354, avg of successful moves: 8.628, loss 703237476843520.0
# CNN made 5007 moves. Successful were 535
# Games: 73500, last 500 games avg score: 58.226, avg of successful moves: 8.882, loss 356906849796096.0
# CNN made 5028 moves. Successful were 509
# Games: 74000, last 500 games avg score: 56.654, avg of successful moves: 8.792, loss 216991176589312.0
# CNN made 4932 moves. Successful were 495
# Games: 74500, last 500 games avg score: 58.328, avg of successful moves: 8.938, loss 96367707947008.0
# CNN made 5007 moves. Successful were 509
# Games: 75000, last 500 games avg score: 60.03, avg of successful moves: 9.114, loss 352562188386304.0
# CNN made 5030 moves. Successful were 538
# Games: 75500, last 500 games avg score: 57.376, avg of successful moves: 8.828, loss 201795817177088.0
# CNN made 5073 moves. Successful were 463
# Games: 76000, last 500 games avg score: 57.206, avg of successful moves: 8.77, loss 120572767895552.0
# CNN made 4941 moves. Successful were 437
# Games: 76500, last 500 games avg score: 59.312, avg of successful moves: 8.86, loss 161435187412992.0
# CNN made 5055 moves. Successful were 464
# Games: 77000, last 500 games avg score: 57.044, avg of successful moves: 8.768, loss 231815155548160.0
# CNN made 5014 moves. Successful were 521
# Games: 77500, last 500 games avg score: 60.202, avg of successful moves: 9.234, loss 66692923260928.0
# CNN made 4894 moves. Successful were 552
# Games: 78000, last 500 games avg score: 55.858, avg of successful moves: 8.818, loss 58540836257792.0
# CNN made 5039 moves. Successful were 507
# Games: 78500, last 500 games avg score: 57.574, avg of successful moves: 8.864, loss 58987881955328.0
# CNN made 4976 moves. Successful were 478
# Games: 79000, last 500 games avg score: 57.828, avg of successful moves: 8.894, loss 46456132075520.0
# CNN made 5014 moves. Successful were 477
# Games: 79500, last 500 games avg score: 57.534, avg of successful moves: 8.902, loss 388406811033600.0
# CNN made 4999 moves. Successful were 489
# Games: 80000, last 500 games avg score: 58.384, avg of successful moves: 8.798, loss 843316895678464.0
# CNN made 4994 moves. Successful were 494
# Games: 80500, last 500 games avg score: 56.686, avg of successful moves: 8.75, loss 1187746227945472.0
# CNN made 5098 moves. Successful were 506
# Games: 81000, last 500 games avg score: 58.294, avg of successful moves: 8.918, loss 472292521934848.0
# CNN made 4905 moves. Successful were 502
# Games: 81500, last 500 games avg score: 57.972, avg of successful moves: 8.976, loss 1214047131271168.0
# CNN made 4924 moves. Successful were 493
# Games: 82000, last 500 games avg score: 59.73, avg of successful moves: 9.03, loss 1363584873398272.0
# CNN made 5069 moves. Successful were 515
# Games: 82500, last 500 games avg score: 58.682, avg of successful moves: 8.846, loss 433929135849472.0
# CNN made 5009 moves. Successful were 503
# Games: 83000, last 500 games avg score: 58.216, avg of successful moves: 8.946, loss 563955244204032.0
# CNN made 4967 moves. Successful were 530
# Games: 83500, last 500 games avg score: 59.19, avg of successful moves: 8.782, loss 466677925937152.0
# CNN made 5093 moves. Successful were 511
# Games: 84000, last 500 games avg score: 59.194, avg of successful moves: 8.864, loss 316109794312192.0
# CNN made 5027 moves. Successful were 572
# Games: 84500, last 500 games avg score: 58.294, avg of successful moves: 8.826, loss 139438629847040.0
# CNN made 4976 moves. Successful were 534
# Games: 85000, last 500 games avg score: 61.042, avg of successful moves: 9.142, loss 185193755312128.0
# CNN made 5077 moves. Successful were 582
# Games: 85500, last 500 games avg score: 60.198, avg of successful moves: 9.022, loss 110996249116672.0
# CNN made 5016 moves. Successful were 573
# Games: 86000, last 500 games avg score: 59.542, avg of successful moves: 8.836, loss 130691937337344.0
# CNN made 5030 moves. Successful were 565
# Games: 86500, last 500 games avg score: 59.29, avg of successful moves: 8.882, loss 166092660015104.0
# CNN made 4924 moves. Successful were 551
# Games: 87000, last 500 games avg score: 56.878, avg of successful moves: 8.842, loss 183990795370496.0
# CNN made 4964 moves. Successful were 470
# Games: 87500, last 500 games avg score: 59.458, avg of successful moves: 8.974, loss 242780962029568.0
# CNN made 5039 moves. Successful were 524
# Games: 88000, last 500 games avg score: 60.562, avg of successful moves: 8.95, loss 68707304865792.0
# CNN made 5111 moves. Successful were 567
# Games: 88500, last 500 games avg score: 59.258, avg of successful moves: 8.808, loss 84329644425216.0
# CNN made 4906 moves. Successful were 549
# Games: 89000, last 500 games avg score: 60.946, avg of successful moves: 9.27, loss 67761237655552.0
# CNN made 5001 moves. Successful were 556
# Games: 89500, last 500 games avg score: 59.444, avg of successful moves: 8.872, loss 430617648955392.0
# CNN made 4932 moves. Successful were 465
# Games: 90000, last 500 games avg score: 57.386, avg of successful moves: 8.622, loss 667595288084480.0
# CNN made 4881 moves. Successful were 403
# Games: 90500, last 500 games avg score: 58.068, avg of successful moves: 8.61, loss 260027084439552.0
# CNN made 5116 moves. Successful were 375
# Games: 91000, last 500 games avg score: 59.498, avg of successful moves: 9.018, loss 252166337986560.0
# CNN made 5076 moves. Successful were 516
# Games: 91500, last 500 games avg score: 59.722, avg of successful moves: 8.82, loss 271569054072832.0
# CNN made 4878 moves. Successful were 494
# Games: 92000, last 500 games avg score: 61.322, avg of successful moves: 8.988, loss 193664303235072.0
# CNN made 5005 moves. Successful were 517
# Games: 92500, last 500 games avg score: 57.584, avg of successful moves: 8.542, loss 190128974725120.0
# CNN made 4957 moves. Successful were 492
# Games: 93000, last 500 games avg score: 58.716, avg of successful moves: 8.874, loss 361621750808576.0
# CNN made 4868 moves. Successful were 454
# Games: 93500, last 500 games avg score: 59.12, avg of successful moves: 8.9, loss 118562849030144.0
# CNN made 4982 moves. Successful were 479
# Games: 94000, last 500 games avg score: 56.79, avg of successful moves: 8.816, loss 83950437400576.0
# CNN made 4867 moves. Successful were 450
# Games: 94500, last 500 games avg score: 56.528, avg of successful moves: 8.682, loss 72413702258688.0
# CNN made 5085 moves. Successful were 510
# Games: 95000, last 500 games avg score: 58.972, avg of successful moves: 8.87, loss 128489667690496.0
# CNN made 5047 moves. Successful were 547
# Games: 95500, last 500 games avg score: 57.538, avg of successful moves: 8.866, loss 77582603124736.0
# CNN made 5005 moves. Successful were 499
# Games: 96000, last 500 games avg score: 57.402, avg of successful moves: 8.944, loss 76191948079104.0
# CNN made 5054 moves. Successful were 511
# Games: 96500, last 500 games avg score: 56.312, avg of successful moves: 8.642, loss 135811127312384.0
# CNN made 5063 moves. Successful were 422
# Games: 97000, last 500 games avg score: 55.59, avg of successful moves: 8.566, loss 131142397198336.0
# CNN made 5031 moves. Successful were 354
# Games: 97500, last 500 games avg score: 58.504, avg of successful moves: 8.928, loss 151098442645504.0
# CNN made 5006 moves. Successful were 360
# Games: 98000, last 500 games avg score: 58.67, avg of successful moves: 8.764, loss 842557760208896.0
# CNN made 4992 moves. Successful were 396
# Games: 98500, last 500 games avg score: 56.792, avg of successful moves: 8.716, loss 83453496262656.0
# CNN made 5046 moves. Successful were 480
# Games: 99000, last 500 games avg score: 57.754, avg of successful moves: 8.734, loss 47645129179136.0
# CNN made 4939 moves. Successful were 460
# Games: 99500, last 500 games avg score: 58.296, avg of successful moves: 8.822, loss 421099162566656.0
# CNN made 5006 moves. Successful were 469
# Games: 100000, last 500 games avg score: 56.466, avg of successful moves: 8.694, loss 2079387209957376.0
# CNN made 5021 moves. Successful were 481
# Games: 100500, last 500 games avg score: 59.81, avg of successful moves: 8.886, loss 1068309629894656.0
# CNN made 5081 moves. Successful were 565
# Games: 101000, last 500 games avg score: 57.172, avg of successful moves: 8.588, loss 1531527489912832.0
# CNN made 5092 moves. Successful were 493
# Games: 101500, last 500 games avg score: 56.154, avg of successful moves: 8.584, loss 442251943608320.0
# CNN made 4908 moves. Successful were 436
# Games: 102000, last 500 games avg score: 59.292, avg of successful moves: 9.024, loss 1082274380513280.0
# CNN made 4990 moves. Successful were 516
# Games: 102500, last 500 games avg score: 58.9, avg of successful moves: 8.964, loss 388910496612352.0
# CNN made 5025 moves. Successful were 544
# Games: 103000, last 500 games avg score: 60.844, avg of successful moves: 9.048, loss 1624665197903872.0
# CNN made 4904 moves. Successful were 518
# Games: 103500, last 500 games avg score: 58.58, avg of successful moves: 8.758, loss 569483068440576.0
# CNN made 4970 moves. Successful were 506
# Games: 104000, last 500 games avg score: 59.816, avg of successful moves: 9.104, loss 614014430216192.0
# CNN made 5040 moves. Successful were 546
# Games: 104500, last 500 games avg score: 58.732, avg of successful moves: 8.768, loss 349706974658560.0
# CNN made 5098 moves. Successful were 538
# Games: 105000, last 500 games avg score: 57.404, avg of successful moves: 8.676, loss 227513343148032.0
# CNN made 4961 moves. Successful were 497
# Games: 105500, last 500 games avg score: 58.782, avg of successful moves: 8.872, loss 64010405806080.0
# CNN made 4960 moves. Successful were 500
# Games: 106000, last 500 games avg score: 56.826, avg of successful moves: 8.766, loss 167121807998976.0
# CNN made 4870 moves. Successful were 424
# Games: 106500, last 500 games avg score: 56.7, avg of successful moves: 8.422, loss 257259464556544.0
# CNN made 4989 moves. Successful were 385
# Games: 107000, last 500 games avg score: 55.566, avg of successful moves: 8.54, loss 591178290429952.0
# CNN made 4998 moves. Successful were 455
# Games: 107500, last 500 games avg score: 57.74, avg of successful moves: 8.848, loss 400713872048128.0
# CNN made 4948 moves. Successful were 482
# Games: 108000, last 500 games avg score: 57.814, avg of successful moves: 8.722, loss 371560204468224.0
# CNN made 4982 moves. Successful were 483
# Games: 108500, last 500 games avg score: 59.588, avg of successful moves: 8.938, loss 176115234635776.0
# CNN made 5052 moves. Successful were 541
# Games: 109000, last 500 games avg score: 58.97, avg of successful moves: 8.928, loss 348652425969664.0
# CNN made 4949 moves. Successful were 478
# Games: 109500, last 500 games avg score: 57.972, avg of successful moves: 8.864, loss 98621164879872.0
# CNN made 5008 moves. Successful were 535
# Games: 110000, last 500 games avg score: 57.45, avg of successful moves: 8.682, loss 133415894515712.0
# CNN made 5016 moves. Successful were 472
# Games: 110500, last 500 games avg score: 57.942, avg of successful moves: 8.778, loss 108338905874432.0
# CNN made 4902 moves. Successful were 471
# Games: 111000, last 500 games avg score: 59.438, avg of successful moves: 8.996, loss 124628240433152.0
# CNN made 4912 moves. Successful were 529
# Games: 111500, last 500 games avg score: 58.09, avg of successful moves: 8.692, loss 90621796679680.0
# CNN made 5047 moves. Successful were 482
# Games: 112000, last 500 games avg score: 58.018, avg of successful moves: 8.766, loss 343826996658176.0
# CNN made 5029 moves. Successful were 518
# Games: 112500, last 500 games avg score: 57.998, avg of successful moves: 8.604, loss 78121403416576.0
# CNN made 4996 moves. Successful were 441
# Games: 113000, last 500 games avg score: 57.236, avg of successful moves: 8.866, loss 154819310387200.0
# CNN made 5045 moves. Successful were 508
# Games: 113500, last 500 games avg score: 60.898, avg of successful moves: 9.098, loss 136418831630336.0
# CNN made 4981 moves. Successful were 540
# Games: 114000, last 500 games avg score: 55.876, avg of successful moves: 8.692, loss 202812550021120.0
# CNN made 4992 moves. Successful were 515
# Games: 114500, last 500 games avg score: 57.46, avg of successful moves: 8.816, loss 64744232845312.0
# CNN made 5014 moves. Successful were 525
# Games: 115000, last 500 games avg score: 59.19, avg of successful moves: 8.98, loss 149352924315648.0
# CNN made 5028 moves. Successful were 514
# Games: 115500, last 500 games avg score: 57.822, avg of successful moves: 8.888, loss 164008074149888.0
# CNN made 5051 moves. Successful were 524
# Games: 116000, last 500 games avg score: 58.65, avg of successful moves: 8.878, loss 262341702713344.0
# CNN made 4905 moves. Successful were 474
# Games: 116500, last 500 games avg score: 59.274, avg of successful moves: 8.942, loss 230759499563008.0
# CNN made 5055 moves. Successful were 495
# Games: 117000, last 500 games avg score: 59.076, avg of successful moves: 8.9, loss 514315991908352.0
# CNN made 5112 moves. Successful were 443
# Games: 117500, last 500 games avg score: 57.966, avg of successful moves: 8.806, loss 459552440975360.0
# CNN made 5041 moves. Successful were 489
# Games: 118000, last 500 games avg score: 58.466, avg of successful moves: 8.968, loss 542098155634688.0
# CNN made 4951 moves. Successful were 540
# Games: 118500, last 500 games avg score: 58.562, avg of successful moves: 8.962, loss 396463733473280.0
# CNN made 4959 moves. Successful were 548
# Games: 119000, last 500 games avg score: 59.866, avg of successful moves: 8.904, loss 403795544637440.0
# CNN made 5050 moves. Successful were 505
# Games: 119500, last 500 games avg score: 56.916, avg of successful moves: 8.72, loss 391197029826560.0
# CNN made 4936 moves. Successful were 489
# Games: 120000, last 500 games avg score: 58.874, avg of successful moves: 8.934, loss 250979702276096.0
# CNN made 4989 moves. Successful were 562
# CPU times: user 5d 8h 23min 11s, sys: 3h 46min 26s, total: 5d 12h 9min 37s
# Wall time: 4d 8h 11min 4s

# %%
# tensorboard --logdir=./logs --bind_all &

print(MAXIMUM_SCORE)
# Out:
# 271

# %%
#
# Save model
#
# v1: 20190329, trained on len(replay_memory) = 294912
#aero_cnn.save("Aero_CNN_v1")

# %% [markdown]
# ## Backup

# %%
#
# Create the moves dictionary
#
moves = {}

for i in range(1, 143):
    old_row, old_column, old_direction = process_move_142(i)
    
    start_row = old_row - 1
    start_col = old_column - 1
    
    if (old_direction == "down"):
        end_row = start_row + 1
        end_col = start_col
    elif (old_direction == "up"):
        end_row = start_row - 1
        end_col = start_col
    elif (old_direction == "right"):
        end_row = start_row
        end_col = start_col + 1
    else:
        end_row = start_row
        end_col = start_col - 1
        
    moves[i] = ((start_row, start_col), (end_row, end_col))
    
print(moves)
